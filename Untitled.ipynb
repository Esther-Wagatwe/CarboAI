# %%
students = [['Mary', 70], ['John', 90], ['James', 89], ['Mercy', 67], ['Lucy', 92]]
type(students)
students
# Out:
# [['Mary', 70], ['John', 90], ['James', 89], ['Mercy', 67], ['Lucy', 92]]

# %%
students[:3]
# Out:
# [['Mary', 70], ['John', 90], ['James', 89]]

# %%
students[3:]
# Out:
# [['Mercy', 67], ['Lucy', 92]]

# %%
students[:]
# Out:
# [['Mary', 70], ['John', 90], ['James', 89], ['Mercy', 67], ['Lucy', 92]]

# %%
for student in students:
    print(student[0], student[1])
# Out:
# Mary 90
# John 90
# James 89
# Mercy 67
# Lucy 92

# %%
list_2 = [['Brian', 88], ['Sophie', 87]]
list_2
# Out:
# [['Brian', 88], ['Sophie', 87]]

# %%
all_students = students + list_2
all_students
# Out:
# [['Mary', 70],
#  ['John', 90],
#  ['James', 89],
#  ['Mercy', 67],
#  ['Lucy', 92],
#  ['Brian', 88],
#  ['Sophie', 87]]

# %%
all_students[0][1] = 90
all_students
# Out:
# [['Mary', 90],
#  ['John', 90],
#  ['James', 89],
#  ['Mercy', 67],
#  ['Lucy', 92],
#  ['Brian', 88],
#  ['Sophie', 87]]

# %%
'Mary' in all_students
# Out:
# True

# %%
duplicated_list = all_students.copy()
duplicated_list
# Out:
# [['Mary', 90],
#  ['John', 90],
#  ['James', 89],
#  ['Mercy', 67],
#  ['Lucy', 92],
#  ['Brian', 88],
#  ['Sophie', 87]]

# %%
temp_list = []
for student in all_students:
    temp_list.append(tuple(student))
student_tuple = tuple(temp_list)
student_tuple
# Out:
# (('Mary', 90),
#  ('John', 90),
#  ('James', 89),
#  ('Mercy', 67),
#  ('Lucy', 92),
#  ('Brian', 88),
#  ('Sophie', 87))
