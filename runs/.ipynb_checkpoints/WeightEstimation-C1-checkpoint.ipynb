# %% [markdown]
# # Let's Train a Faster R-CNN model for food detection
# The Faster R-CNN model will be trained on a COCO-formatted dataset.
# It will detect the different food items in an image

# %%
import detectron2
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg
from detectron2.model_zoo import get_config_file
from detectron2.data.datasets import register_coco_instances
from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader
from detectron2.layers import ShapeSpec
from detectron2.modeling.roi_heads import FastRCNNOutputLayers #importing a new predictor
import os
import torch
import json

# Paths
data_dir = "/home/aojwang/data/Dataset"
train_images = "/home/aojwang/data/Dataset/images/"
train_annotations = os.path.join(data_dir, "coco_train.json")
val_images = "/home/aojwang/data/Dataset/images/OK 1"
val_annotations = os.path.join(data_dir, "coco_val.json")

# Register datasets
register_coco_instances("food_train", {}, train_annotations, train_images)
register_coco_instances("food_val", {}, val_annotations, val_images)

# Load class names from COCO JSON
with open(train_annotations, 'r') as f:
    coco_data = json.load(f)
    class_names = [category['name'] for category in coco_data['categories']]

# Set class names in metadata
MetadataCatalog.get("food_train").thing_classes = class_names
MetadataCatalog.get("food_val").thing_classes = class_names

# Custom trainer with evaluator
class TrainerWithEvaluator(DefaultTrainer):
    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        if output_folder is None:
            output_folder = os.path.join(cfg.OUTPUT_DIR, "inference")
        return COCOEvaluator(dataset_name, cfg, False, output_folder)

# Configure Faster R-CNN
cfg = get_cfg()
cfg.merge_from_file(get_config_file("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("food_train",)
cfg.DATASETS.TEST = ("food_val",) 
cfg.TEST.EVAL_PERIOD = 500  # Run evaluation every 500 iterations
cfg.DATALOADER.NUM_WORKERS = 4
cfg.MODEL.WEIGHTS = "detectron2://COCO-Detection/faster_rcnn_R_50_FPN_3x/137849458/model_final_280758.pkl"
cfg.SOLVER.IMS_PER_BATCH = 4
cfg.SOLVER.BASE_LR = 0.00025
cfg.SOLVER.MAX_ITER = 5000
cfg.SOLVER.STEPS = []  # No learning rate decay
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 512
cfg.MODEL.ROI_HEADS.NUM_CLASSES = len(class_names)

# Train model
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = TrainerWithEvaluator(cfg)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
trainer.model.to(device)

num_inputs = trainer.model.roi_heads.box_predictor.cls_score.in_features

trainer.model.roi_heads.box_predictor = FastRCNNOutputLayers(
    input_shape=ShapeSpec(channels=num_inputs),
    num_classes=cfg.MODEL.ROI_HEADS.NUM_CLASSES,
    box2box_transform=trainer.model.roi_heads.box_predictor.box2box_transform
).to(device)

trainer.resume_or_load(resume=False)

trainer.train()

# Run evaluation after training
evaluator = COCOEvaluator("food_val", cfg, False, output_dir=cfg.OUTPUT_DIR)
val_loader = build_detection_test_loader(cfg, "food_val")
print("🔍 Running Evaluation...")
inference_on_dataset(trainer.model, val_loader, evaluator)
# Out:
# [03/13 10:57:18 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=248, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=988, bias=True)
#     )
#   )
# )
# [03/13 10:57:18 d2.data.datasets.coco]: Loaded 1604 images in COCO format from /home/aojwang/data/Dataset/coco_train.json
# [03/13 10:57:18 d2.data.build]: Removed 11 images with no usable annotations. 1593 images left.
# [03/13 10:57:18 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [03/13 10:57:18 d2.data.build]: Using training sampler TrainingSampler
# [03/13 10:57:18 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [03/13 10:57:18 d2.data.common]: Serializing 1593 elements to byte tensors and concatenating them all ...
# [03/13 10:57:18 d2.data.common]: Serialized dataset takes 0.49 MiB
# [03/13 10:57:18 d2.data.build]: Making batched data loader with batch_size=4
# [03/13 10:57:18 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from detectron2://COCO-Detection/faster_rcnn_R_50_FPN_3x/137849458/model_final_280758.pkl ...
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (248, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (248,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (988, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (988,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# [03/13 10:57:18 d2.engine.train_loop]: Starting training from iteration 0
# [03/13 10:57:26 d2.utils.events]:  eta: 0:30:18  iter: 19  total_loss: 5.84  loss_cls: 5.614  loss_box_reg: 0.1932  loss_rpn_cls: 0.007344  loss_rpn_loc: 0.01103    time: 0.3620  last_time: 0.3628  data_time: 0.0844  last_data_time: 0.0090   lr: 4.9953e-06  max_mem: 11058M
# | White Bread Avocado Spread   | nan    | White Bread Honey Spread                                     | nan    | White Bread Jam Spread       | nan    |
# | Brown Bread Peanut Spread    | nan    | Butternut Boiled                                             | nan    | Boiled Yellow Maize          | nan    |
# | Boiled Mashed Banana         | nan    | Boiled Green Banana Mashed                                   | nan    | Bhajia                       | nan    |
# | Irish Potato Mashed          | nan    | Tadhikaldal                                                  | nan    | White Bread Butter Spread    | nan    |
# | Wholemeal Bread              | nan    | Brown Rice Boiled                                            | nan    | Black Beans Carrot           | nan    |
# | Butternut Spinach            | nan    | Chicken Pea Avocado                                          | nan    | Peas Stew                    | nan    |
# | weetabix                     | nan    | Vegetable Samosa                                             | nan    | Cumin Rice                   | nan    |
# | Potato Wedges                | nan    |                                                              |        |                              |        |
# OrderedDict([('bbox',
#               {'AP': 5.800722386875226,
#                'AP50': 16.633496925993274,
#                'AP75': 1.4867391911604955,
#                'APs': nan,
#                'APm': nan,
#                'APl': 5.800722386875226,
#                'AP-Beans': nan,
#                'AP-Orange Juice': nan,
#                'AP-Cola': nan,
#                'AP-Fanta': nan,
#                'AP-Apple juice': nan,
#                'AP-Energy Drink': nan,
#                'AP-Coffee': nan,
#                'AP-Cola Sugarless': nan,
#                'AP-Carbonated Sprite': nan,
#                'AP-Broth': nan,
#                'AP-Carbonated Coke': nan,
#                'AP-Olive Oil': nan,
#                'AP-Sunflower Seeds': 0.0,
#                'AP-Sesame Seeds': 13.861386138613863,
#                'AP-Pumpkin Seeds': 50.0,
#                'AP-Poppy Seeds': 3.0000000000000004,
#                'AP-Peanut': 0.0,
#                'AP-Mozzarella': nan,
#                'AP-Macadamia': 0.0,
#                'AP-Hazelnut': 0.0,
#                'AP-Ghee': nan,
#                'AP-Flax': 1.6666666666666667,
#                'AP-Coconut': 0.0,
#                'AP-Chia Seeds': 1.3333333333333333,
#                'AP-Cashewnut': 10.051357767355684,
#                'AP-Almond': 2.0983711274353234,
#                'AP-Apple': 0.07425742574257425,
#                'AP-Avocado': 1.7487984823327047,
#                'AP-Pawpaw': 9.665905052043664,
#                'AP-Ripe Banana': 33.2956152758133,
#                'AP-Water Melon': 0.0,
#                'AP-Blueberry': 0.0,
#                'AP-Custard Apple': 0.0,
#                'AP-Dates': nan,
#                'AP-Guava': nan,
#                'AP-Kiwi': 1.6682738669238188,
#                'AP-Lemon': 3.3663366336633667,
#                'AP-Mango': 0.0,
#                'AP-Orange': 10.228430343034303,
#                'AP-Passion': 0.0,
#                'AP-Pear': 0.0,
#                'AP-Pineapple': 19.245984094977004,
#                'AP-Plum': 0.0,
#                'AP-Raspberry': 0.0,
#                'AP-Strawberry': 0.0,
#                'AP-Tangerine': 0.0,
#                'AP-Thorn Melon': nan,
#                'AP-Bacon': nan,
#                'AP-Beef Roast': nan,
#                'AP-Chicken': nan,
#                'AP-Boiled Egg': nan,
#                'AP-Fish Fry': nan,
#                'AP-Ham': nan,
#                'AP-Lamb Stew': nan,
#                'AP-Liver Fry': nan,
#                'AP-Matumbo Fry': nan,
#                'AP-Omena': nan,
#                'AP-Pork Fry': nan,
#                'AP-Sausage': nan,
#                'AP-Lettuce': nan,
#                'AP-Spinach Cooked': 4.812341699286208,
#                'AP-Tomato': 3.7541254125412538,
#                'AP-Green Cabbage Cooked': 20.251112067728506,
#                'AP-Salad': nan,
#                'AP-Onions': nan,
#                'AP-Cucumber': 0.10752688172043011,
#                'AP-Pumpkin': nan,
#                'AP-Carrot': 14.326858457170582,
#                'AP-Sprout Tomato': nan,
#                'AP-French beans': nan,
#                'AP-Cauliflower': nan,
#                'AP-Mushroom': nan,
#                'AP-Saget': 71.08910891089108,
#                'AP-Red Cabbage': nan,
#                'AP-Broccoli': nan,
#                'AP-White Chapati': nan,
#                'AP-Brown Chapati': nan,
#                'AP-White bread': nan,
#                'AP-Brown Bread': nan,
#                'AP-Cassava Boiled': nan,
#                'AP-Cake': nan,
#                'AP-Butternut Soup': nan,
#                'AP-Butternut': nan,
#                'AP-Black Beans': nan,
#                'AP-Biscuit': nan,
#                'AP-Boiled Banana': nan,
#                'AP-White Ugali': nan,
#                'AP-White Rice Boiled': nan,
#                'AP-Bread': nan,
#                'AP-Arrowroots': nan,
#                'AP-Scone': nan,
#                'AP-Rosecoco': nan,
#                'AP-Irish Potato': nan,
#                'AP-Sweet Potato': nan,
#                'AP-Potato Crisps': nan,
#                'AP-Boiled Peas': nan,
#                'AP-Pasta': nan,
#                'AP-Pancake': nan,
#                'AP-Oat Porridge': nan,
#                'AP-Noodles': nan,
#                'AP-Green bananas': nan,
#                'AP-Maize': nan,
#                'AP-Yam': nan,
#                'AP-Soya Beans': nan,
#                'AP-Sorghum Porridge': nan,
#                'AP-Potato Chips': nan,
#                'AP-Terere': 18.503850385038504,
#                'AP-Githeri': nan,
#                'AP-Hotdog': nan,
#                'AP-Hamburger': nan,
#                'AP-Kamande': nan,
#                'AP-Yellow Beans': nan,
#                'AP-Zucchini': nan,
#                'AP-Radish': nan,
#                'AP-Beetroot': 0.0,
#                'AP-Red Bell pepper': 0.0,
#                'AP-Asparagus': nan,
#                'AP-Red Syrup': nan,
#                'AP-Sugar': nan,
#                'AP-Honey': nan,
#                'AP-Samosa': nan,
#                'AP-Artificial Sweetener': nan,
#                'AP-Eggplant': nan,
#                'AP-Murenda': 0.0,
#                'AP-Managu': 6.25,
#                'AP-Thabai': 0.7793684773882793,
#                'AP-Mrenda': nan,
#                'AP-Bitter Lemon': nan,
#                'AP-Butternut Beans': nan,
#                'AP-Cereal': nan,
#                'AP-Chocolate': nan,
#                'AP-Mbaazi': nan,
#                'AP-Chick Peas': nan,
#                'AP-Cornflakes': nan,
#                'AP-Naan': nan,
#                'AP-Dalmakhi': nan,
#                'AP-Maize Porridge': nan,
#                'AP-Ndengu': nan,
#                'AP-Milk': nan,
#                'AP-Ribena': nan,
#                'AP-Fermented Milk': nan,
#                'AP-White Tea': nan,
#                'AP-Black Tea': nan,
#                'AP-Coconut Water': 0.0,
#                'AP-Flavored Water': nan,
#                'AP-Tropical Juice': nan,
#                'AP-Spirit': nan,
#                'AP-White Sugar': nan,
#                'AP-Brown Sugar': nan,
#                'AP-Avocado Red Pepper': nan,
#                'AP-Avocado Tomato': nan,
#                'AP-Green Cabbage': nan,
#                'AP-Cabbage Sprout': nan,
#                'AP-Beetroot Radish': nan,
#                'AP-Avocado Green Cabbage': nan,
#                'AP-Cabbage Sprout Tomato': nan,
#                'AP-Yellow Bell Pepper': 0.0,
#                'AP-Green Bell Pepper': 8.363036303630363,
#                'AP-Carrot Green Cabbage': nan,
#                'AP-Carrot Zucchini': nan,
#                'AP-Cucumber Lettuce': nan,
#                'AP-Cucumber Lettuce Tomato': nan,
#                'AP-Fried Egg Plant': nan,
#                'AP-Kitojo': nan,
#                'AP-Kunde': 0.0,
#                'AP-Lettuce Red Bell Pepper': nan,
#                'AP-Lettuce Tomato': nan,
#                'AP-Nderema': 0.0,
#                'AP-Onion Tomato': nan,
#                'AP-Onion Tomato Avocado': nan,
#                'AP-Cooked Mushroom': nan,
#                'AP-Onion Tomato Carrot': nan,
#                'AP-Paneel': nan,
#                'AP-Plum Tomato': nan,
#                'AP-Pumpkin Leaves': 2.913906225787414,
#                'AP-Red Green Yellow Bell Pepper': nan,
#                'AP-Sukumawiki': 6.89537708470095,
#                'AP-Tomato Cucumber Carrot': nan,
#                'AP-Avocado Lettuce': nan,
#                'AP-Avocado Cucumber Carrot': nan,
#                'AP-Red Cabbage Cooked': 3.8943894389438944,
#                'AP-Red Cabbage Cucumber Plum Tomato Yellow Bell Pepper Cucumber': nan,
#                'AP-Chicken Makhni': nan,
#                'AP-Chicken Skin': nan,
#                'AP-Meatballs': nan,
#                'AP-Mincemeat': nan,
#                'AP-Kachumbari': nan,
#                'AP-Omelette': nan,
#                'AP-Biryani': nan,
#                'AP-Spaghetti': nan,
#                'AP-Brown Ugali': nan,
#                'AP-Biryani Lamb': nan,
#                'AP-Fish Fillet': nan,
#                'AP-Onion Tomato Omelette': nan,
#                'AP-Cabbage Sprout Chicken': nan,
#                'AP-Scrambled Eggs': nan,
#                'AP-Egg Fry': nan,
#                'AP-Chicken Roast': nan,
#                'AP-Chicken Drumstick': nan,
#                'AP-Beef Fry': nan,
#                'AP-Mashed Potato': nan,
#                'AP-Lamb Biryani': nan,
#                'AP-Guinness Beer': nan,
#                'AP-White Cap Beer': nan,
#                'AP-Natural Yoghurt': nan,
#                'AP-Vanilla Yoghurt': nan,
#                'AP-Strawberry Yoghurt': nan,
#                'AP-Jack Daniels Spirit': nan,
#                'AP-Gin & Tonic Spirit': nan,
#                'AP-Water Tonic': nan,
#                'AP-Red Wine': nan,
#                'AP-White Wine': nan,
#                'AP-Butter': nan,
#                'AP-Mango Grape Apple': 3.284179481777964,
#                'AP-Red Grapes': 0.0,
#                'AP-Green Grapes': nan,
#                'AP-Strawberry Banana': nan,
#                'AP-Strawberry Pear Orange': 2.7967898830699403,
#                'AP-Tree Tomato': 0.0,
#                'AP-Watermelon Mango Kiwi': 6.732673267326733,
#                'AP-Avocado Pawpaw': 0.38253825382538253,
#                'AP-Banana Watermelon Pawpaw': 0.0,
#                'AP-Strawberry Banana Watermelon': 0.0,
#                'AP-Lemon Mango Kiwi': nan,
#                'AP-Brown Bread Margarine Spread': nan,
#                'AP-White Bread Avocado Spread': nan,
#                'AP-White Bread Honey Spread': nan,
#                'AP-White Bread Jam Spread': nan,
#                'AP-Brown Bread Peanut Spread': nan,
#                'AP-Butternut Boiled': nan,
#                'AP-Boiled Yellow Maize': nan,
#                'AP-Boiled Mashed Banana': nan,
#                'AP-Boiled Green Banana Mashed': nan,
#                'AP-Bhajia': nan,
#                'AP-Irish Potato Mashed': nan,
#                'AP-Tadhikaldal': nan,
#                'AP-White Bread Butter Spread': nan,
#                'AP-Wholemeal Bread': nan,
#                'AP-Brown Rice Boiled': nan,
#                'AP-Black Beans Carrot': nan,
#                'AP-Butternut Spinach': nan,
#                'AP-Chicken Pea Avocado': nan,
#                'AP-Peas Stew': nan,
#                'AP-weetabix': nan,
#                'AP-Vegetable Samosa': nan,
#                'AP-Cumin Rice': nan,
#                'AP-Potato Wedges': nan})])

# %%
import torch
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.transforms import ToTensor
import json
from torch.utils.data import DataLoader
from torchvision.datasets import CocoDetection

# Load class names from JSON
json_path = "/home/aojwang/data/Dataset/coco_train.json"
with open(json_path, "r") as f:
    coco_data = json.load(f)
    class_names = [category["name"] for category in coco_data["categories"]]

num_classes = len(class_names) + 1  # Add 1 for background class

# Load pre-trained Faster R-CNN
model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)

# Replace classifier with a new one
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

# Move model to GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Define transformations
transform = ToTensor()

# Load Training and Validation datasets
train_dataset = CocoDetection(root="/home/aojwang/data/Dataset/images/", 
                              annFile=json_path, 
                              transform=transform)

val_dataset = CocoDetection(root="/home/aojwang/data/Dataset/images/OK 1", 
                            annFile="/home/aojwang/data/Dataset/coco_val.json", 
                            transform=transform)

# DataLoaders
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, collate_fn=lambda x: tuple(zip(*x)))
val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False, collate_fn=lambda x: tuple(zip(*x)))

# Define optimizer and learning rate
optimizer = torch.optim.Adam(model.parameters(), lr=0.00025)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    model.train()
    for images, targets in train_loader:
        images = [img.to(device) for img in images]
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

    # Validation step
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for images, targets in val_loader:
            images = [img.to(device) for img in images]
            targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

            loss_dict = model(images, targets)
            val_loss += sum(loss for loss in loss_dict.values()).item()

    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {losses.item()}, Val Loss: {val_loss/len(val_loader)}")

# Save the trained model
torch.save(model.state_dict(), "food_detector.pth")
# Out:
# Total Classes in Dataset: 247
# Configured Number of Classes: 247

# %%
from PIL import Image
image_path = "/home/aojwang/data/Dataset/images/OK 3b/1AppleJuice.JPG"
image = Image.open(image_path)
image = image.convert("RGB")  # Ensure EXIF is ignored
image.save(image_path)  # Overwrite the image without EXIF metadata
# Out:
# Fixed: /home/aojwang/data/Dataset/images/OK 4/2Weetabix.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/5Chicken.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/3Lambstew.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/1BrownUgalimillet.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/3Omena.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/2Chickenpeas.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/2Ndengu.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/3Matumbofried.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/1Ndengu.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/4Blackbeans.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/2Whitebutternutbeans.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/3Githeri.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/2Plumtomatoes.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/5BrownUgalimillet.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/4Meatballs.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/1Mbaazi.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/4Kamande.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/1Chickenpeas.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/1Vegetablesamosa.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/4Fish.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/3Boiledbanana.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/5Lambstew.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/3NaturalYoghurt.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/2Red pepperGreenpepperYellowpepper.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/6Chicken.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/1Butternutboiled.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/2Cabbage.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/4Kiwi.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/2Friedpork.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/3Liver.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/1CucumberLettuce.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/1Mincedmeat.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/4Butternutsoup.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/4Oatporridge.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/4Soyabeans.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/2Liver.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/3Rosecoco.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/1CucumberLettuceTomatoes.JPG
# Fixed: /home/aojwang/data/Dataset/images/OK 4/
jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEIN BATCH/3FishFillet.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEIN BATCH/1MatumboFried.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEIN BATCH/1Chickenskin.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEIN BATCH/2Omena.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEIN BATCH/3Sausage.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEIN BATCH/1ChickenRoast.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEIN BATCH/2EggBoiled.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEIN BATCH/1FishFillet.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEIN BATCH/1ChickenDrumsticks.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEIN BATCH/1Omena.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEIN BATCH/2ChickenRoast.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEIN BATCH/1Fish.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/2ChickenCucumber.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1ChickenSpinach.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1LambSpinach.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1LiverFrenchbeans.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1LiverSpinach.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/2FishCucumber.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1EggFrenchbeansMushrooms.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/3FishCucumber.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/2ChickenCabbage.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1ChickenLettuceAvocado.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1EggLettuce.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1ChickenCucumber.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1ChickenCabbage.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1ChickenEggSpinach.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1DrumstickSalad.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/3PorkBroccoli.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/3ChickenCabbage.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1DrumstickSproutTomato.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/2ChickenSpinach.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/2MeatballsRedCabbage.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1EggSpinach.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/2FishRedCabbage.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/3ChickenPumpkin.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/3FishRedCabbage.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1HamSalad.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/3FishSpinach.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1SausageEggSpinach.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1SausageRedpepperLettuce.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1BeefRoastVeg.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/3MeatballsRedCabbage.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1FishSpinach.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/2ChickenPumpkin.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1FishCabbage.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1PorkBroccoli.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1FishCucumber.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/2OmeletteOnionTomato.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1MatumboSpinach.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1BaconSpinach.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1OmeletteBeanCucumber2.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1EggAvocado.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/2FishCabbage.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1ChickenAvocadoTomatoOnions.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1SausageSpinach.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1OmenaSpinach.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1SausageAvocadoTomatoOnions.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1PorkSpinach.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1OmenaSaget.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1BaconLettuceAvocado.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1ChickenPumpkin.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1BaconSpinachAvocado.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/2PorkBroccoli.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1LambSaget.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1DrumstickRedpepperLettuce.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/3ChickenCucumber.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/3ChickenSpinach.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1MatumboSaget.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1LiverSaget.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1OmeletteOnionTomato.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1OmeletteBeanCucumber.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1EggCarrot.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/2FishSpinach.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1SausageSalad.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1FishRedCabbage.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1EggLettuceAvocado.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1OnionTomatoFish.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1DrumstickCarrotTomato.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1EggTomato.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1MeatballsRedCabbage.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1SausageSpinachAvocado.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1EggFrenchbeans.jpg
# Fixed: /home/aojwang/data/Dataset/images/PROTEINVEGIESBATCH/1EggFrenchbeansCauliflower.jpg
# All images processed successfully.

# %% [markdown]
# # Image augmentation

# %%
import cv2
import json
import numpy as np
import albumentations as A
from pycocotools.coco import COCO
from albumentations.pytorch import ToTensorV2


# Load COCO JSON Annotations
coco_path = "/home/aojwang/data/Dataset/coco.json"
with open(coco_path, "r") as f:
    coco_data = json.load(f)

# Initialize COCO API
coco = COCO(coco_path)

# Define Augmentations
transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.3),
    A.Rotate(limit=30, p=0.5),
    A.RandomBrightnessContrast(p=0.2),
    A.GaussianBlur(p=0.2),
    A.RandomScale(scale_limit=0.2, p=0.5),
    A.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.1, rotate_limit=20, p=0.5),
], bbox_params=A.BboxParams(format="coco", label_fields=["category_id"]))

# Process Each Image In-Memory
augmented_images = []
for img_info in coco_data["images"]:
    img_id = img_info["id"]
    img_path = f"/home/aojwang/data/MergeDataset/images/{img_info['file_name']}"  # Adjust path if necessary
    image = cv2.imread(img_path)
    
    if image is None:
        continue
    
    # Get Annotations for this Image
    ann_ids = coco.getAnnIds(imgIds=[img_id])
    annotations = coco.loadAnns(ann_ids)

    # Extract Bounding Boxes & Categories
    bboxes = []
    category_ids = []
    for ann in annotations:
        bbox = ann["bbox"]  # COCO format: [x, y, width, height]
        bboxes.append(bbox)
        category_ids.append(ann["category_id"])

    # Apply Augmentations
    transformed = transform(image=image, bboxes=bboxes, category_id=category_ids)
    aug_img = transformed["image"]
    aug_bboxes = transformed["bboxes"]

    # Store Augmented Image and Annotations
    augmented_images.append({
        "image": aug_img,
        "bboxes": aug_bboxes,
        "category_ids": category_ids,
    })

def visualize_augmented_images(augmented_images, num_images=5):
    fig, axes = plt.subplots(1, num_images, figsize=(15, 5))

    for i, aug_data in enumerate(augmented_images[:num_images]):
        image = aug_data["image"]
        bboxes = aug_data["bboxes"]
        category_ids = aug_data["category_ids"]

        # Convert from OpenCV (BGR) to Matplotlib (RGB)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        ax = axes[i]
        ax.imshow(image)
        ax.set_title(f"Augmented Image {i+1}")

        # Draw bounding boxes
        for bbox in bboxes:
            x, y, w, h = bbox
            rect = patches.Rectangle(
                (x, y), w, h, linewidth=2, edgecolor="r", facecolor="none"
            )
            ax.add_patch(rect)

        ax.axis("off")

    plt.tight_layout()
    plt.show()

# Call the function to visualize
visualize_augmented_images(augmented_images)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %% [markdown]
# ## Let's visualize the model's performance over epochs

# %%
import json
import matplotlib.pyplot as plt

# Path to Detectron2 metrics log file
log_file = "output/metrics.json"

# Lists to store training and validation loss
iterations, loss_values, val_loss_values = [], [], []

with open(log_file, "r") as f:
    for line in f:
        log = json.loads(line)
        if "total_loss" in log:  # Training loss
            iterations.append(log["iteration"])
            loss_values.append(log["total_loss"])
        if "validation_loss" in log:  # Validation loss (if available)
            val_loss_values.append(log["validation_loss"])

# Ensure unique, sorted iterations for cleaner plots
sorted_pairs = sorted(set(zip(iterations, loss_values)))
sorted_iterations, sorted_losses = zip(*sorted_pairs)

# Convert iterations to epochs (Adjust iterations_per_epoch)
iterations_per_epoch = 401  # Change based on dataset size & batch size
epochs = [it / iterations_per_epoch for it in sorted_iterations]

# Plot training loss
plt.plot(epochs, sorted_losses, label="Training Loss", linewidth=2)

# If validation loss is available, plot it
if val_loss_values:
    plt.plot(epochs[:len(val_loss_values)], val_loss_values, label="Validation Loss", linestyle="dashed", linewidth=2)

# Plot formatting
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Performance Over Epochs")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Image augmentation

# %%
# ! pip install albumentations opencv-python numpy
import cv2
import numpy as np
import albumentations as A
import os

def load_yolo_annotations(txt_path):
    """Load YOLO annotations from a .txt file."""
    boxes = []
    with open(txt_path, "r") as f:
        for line in f.readlines():
            values = line.strip().split()
            class_id = int(values[0])
            x_center, y_center, width, height = map(float, values[1:])
            boxes.append([x_center, y_center, width, height, class_id])
    return boxes

def save_yolo_annotations(txt_path, boxes):
    """Save YOLO annotations to a .txt file."""
    with open(txt_path, "w") as f:
        for box in boxes:
            f.write(f"{int(box[4])} {box[0]} {box[1]} {box[2]} {box[3]}\n")

def augment_image(image, bboxes):
    """Perform augmentations while skipping invalid ones."""
    transform = A.Compose([
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.5),
        A.RandomBrightnessContrast(p=0.2),
        A.Affine(scale=(0.95, 1.05), translate_percent=(-0.05, 0.05), rotate=(-10, 10), p=0.5)
    ], bbox_params=A.BboxParams(format='yolo', label_fields=[]))

    try:
        transformed = transform(image=image, bboxes=[b[:4] for b in bboxes])

        # Check if any bounding box is invalid
        for bbox in transformed["bboxes"]:
            if any(coord < 0 or coord > 1 for coord in bbox):
                print("Skipping augmentation due to invalid bbox:", bbox)
                return image, bboxes

        return transformed["image"], transformed["bboxes"]

    except Exception as e:
        print("Error during augmentation:", e)
        return image, bboxes  # Skip and return original data

def augment_dataset(original_images_dir, original_labels_dir):
    """Augment dataset and save only the augmented images and labels."""
    image_files = [f for f in os.listdir(original_images_dir) if f.endswith(('.jpg', '.JPG'))]

    for img_file in image_files:
        img_path = os.path.join(original_images_dir, img_file)
        label_path = os.path.join(original_labels_dir, img_file.replace('.jpg', '.txt').replace('.JPG', '.txt'))
        
        if not os.path.exists(label_path):
            continue

        image = cv2.imread(img_path)

        # Load YOLO bounding boxes (normalized values)
        boxes = load_yolo_annotations(label_path)

        # Generate and save augmented image and annotations
        augmented_image, augmented_boxes = augment_image(image, boxes)

        # Preserve original class labels
        aug_boxes = [b + [boxes[i][4]] for i, b in enumerate(augmented_boxes)]

        # Save augmented image and label
        aug_img_name = f"aug_{img_file}"
        aug_label_name = f"aug_{img_file.replace('.jpg', '.txt').replace('.JPG', '.txt')}"
        cv2.imwrite(os.path.join(original_images_dir, aug_img_name), augmented_image)
        save_yolo_annotations(os.path.join(original_labels_dir, aug_label_name), aug_boxes)

# Define dataset directories
original_images_dir = "/home/aojwang/data/yolo_dataset/val/images"
original_labels_dir = "/home/aojwang/data/yolo_dataset/val/labels"

# Process and save the augmented dataset
augment_dataset(original_images_dir, original_labels_dir)

# %%
# !ls /home/aojwang/data/yolo_dataset
# Out:
# test  train  val  yolo.yaml

# %% [markdown]
# ## Visualize augmented images

# %%
# visualize images
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the image
image_path = "/home/aojwang/data/DrOjwang/Day 1/ad .jpg"
img = mpimg.imread(image_path)

plt.figure(figsize=(6, 6))
plt.imshow(img)
plt.axis('off')
plt.title('ad.jpg')
plt.show()

# %%
import os
import cv2
import matplotlib.pyplot as plt
import random

# Define dataset directories
image_dir = "/home/aojwang/data/yolo_dataset/val/images"
label_dir = "/home/aojwang/data/yolo_dataset/val/labels"

# Dynamically list all images starting with "aug_"
augmented_images = [img for img in os.listdir(image_dir) if img.startswith("aug_")]

# Count total images and labels
total_images = len(os.listdir(image_dir))
total_labels = len(os.listdir(label_dir))
total_augmented = len(augmented_images)

print(f"Total Images: {total_images}")
print(f"Total Labels: {total_labels}")
print(f"Total Augmented Images: {total_augmented}")

# Choose a random augmented image for visualization
if total_augmented == 0:
    print("No augmented images found.")
else:
    random_image = random.choice(augmented_images)
    image_path = os.path.join(image_dir, random_image)
    
    # Handle different file extensions
    label_path = os.path.join(label_dir, random_image.rsplit(".", 1)[0] + ".txt")

    # Function to read YOLO annotations
    def read_yolo_annotations(txt_file):
        boxes = []
        if not os.path.exists(txt_file):
            print(f"Warning: Label file not found for {random_image}")
            return boxes
        with open(txt_file, "r") as f:
            for line in f:
                values = line.strip().split()
                class_id = int(values[0])
                x_center, y_center, width, height = map(float, values[1:])
                boxes.append((class_id, x_center, y_center, width, height))
        return boxes

    # Read image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for display

    # Read bounding boxes
    bboxes = read_yolo_annotations(label_path)
    print(bboxes)
    h, w, _ = image.shape  # Get image dimensions

    # Draw bounding boxes
    for class_id, x_center, y_center, width, height in bboxes:
        x1 = int((x_center - width / 2) * w)
        y1 = int((y_center - height / 2) * h)
        x2 = int((x_center + width / 2) * w)
        y2 = int((y_center + height / 2) * h)

        # Draw rectangle and label
        cv2.rectangle(image, (x1, y1), (x2, y2), (255, 0, 0), 5)
        cv2.putText(image, f"Class {class_id}", (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)

    # Display the image with bounding boxes
    plt.figure(figsize=(10, 6))
    plt.imshow(image)
    plt.axis("off")
    plt.title(f"Augmented Image: {random_image}")
    plt.show()

# %% [markdown]
# # Train yolo model

# %%
# !cat /home/aojwang/data/yolo_dataset/yolo.yaml

# %%
from ultralytics import YOLO 

# model = YOLO("yolo11n.pt")
# results = model.train(data="/home/aojwang/data/yolo_dataset2/yolo.yaml", epochs=50, hsv_v=0.5, translate=0.2, scale=0.3, shear=10, erasing=0.2, batch=4, imgsz=640, project="runs/train",  name='yolo11_food_detection')
model = YOLO("yolov8n.pt")
results = model.train(data="/home/aojwang/data/yolo_dataset/yolo.yaml",epochs=100,batch=4,imgsz=640,hsv_v=0.5,translate=0.2,scale=0.3,shear=10,erasing=0.2,flipud=0.3,fliplr=0.5,mosaic=1.0,mixup=0.5,box=0.05,cls=0.5,dfl=1.5,project="runs/train",name='yolo11_food_detection_improved')
# Out:
# New https://pypi.org/project/ultralytics/8.3.161 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.69 🚀 Python-3.10.12 torch-2.5.1+cu124 CUDA:0 (NVIDIA A10G, 22836MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/home/aojwang/data/yolo_dataset/yolo.yaml, epochs=100, time=None, patience=100, batch=4, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=runs/train, name=yolo11_food_detection_improved9, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.5, degrees=0.0, translate=0.2, scale=0.3, shear=10, perspective=0.0, flipud=0.3, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.5, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.2, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/train/yolo11_food_detection_improved9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751380121.375416 1169846 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751380121.400772 1169846 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Overriding model.yaml nc=80 with nc=264
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1   1136296  ultralytics.nn.modules.head.Detect           [264, [64, 128, 256]]
# Model summary: 225 layers, 3,395,832 parameters, 3,395,816 gradients, 10.0 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/train/yolo11_food_detection_improved9', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /opt/dlami/nvme/aojwang/yolo_dataset/train/labels.cache... 9652 images, 640 backgrounds, 0 corrupt: 100%|██████████|
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.8' (you have '2.0.5'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# val: Scanning /opt/dlami/nvme/aojwang/yolo_dataset/val/labels.cache... 2758 images, 188 backgrounds, 0 corrupt: 100%|██████████| 2758
# Plotting labels to runs/train/yolo11_food_detection_improved9/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/yolo11_food_detection_improved9
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100     0.921G    0.01173      5.106      1.972         17        640: 100%|██████████| 2413/2413 [06:37<00:00,  6.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 345/345 [01:24<00:00,  4.0
#                    all       2758       4142      0.613     0.0538     0.0317     0.0178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100     0.904G    0.01154      4.294      1.947         12        640: 100%|██████████| 2413/2413 [06:19<00:00,  6.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 345/345 [01:17<00:00,  4.4
#                    all       2758       4142      0.538      0.095     0.0785     0.0469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      0.91G    0.01148      3.979      1.911         22        640: 100%|██████████| 2413/2413 [06:19<00:00,  6.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 345/345 [01:09<00:00,  4.9
#                    all       2758       4142       0.51       0.15       0.13     0.0774
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100     0.908G    0.01155      3.827      1.895         19        640: 100%|██████████| 2413/2413 [06:23<00:00,  6.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 345/345 [01:04<00:00,  5.3
#                    all       2758       4142      0.465      0.232      0.187      0.106
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100     0.914G     0.0114      3.537      1.862         20        640: 100%|██████████| 2413/2413 [06:04<00:00,  6.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 345/345 [01:04<00:00,  5.3
#                    all       2758       4142      0.418      0.278      0.238      0.139
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100     0.908G    0.01127      3.319      1.838         21        640:  59%|█████▉    | 1424/2413 [03:37<01:49,  9.04it/s]

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
# yolo has its own augmentation: https://docs.ultralytics.com/guides/yolo-data-augmentation/
#results = model.train(data="/home/aojwang/data/y1_dataset2/y1.yaml",epochs=30, hsv_v=0.5 , translate=0.3,scale=0.4, shear=10,erasing=0.2,  batch=4, imgsz=640, project='runs/train', name='AUG2_food_detection')
#results = model.train(data="/home/aojwang/data/y1_dataset2/y1.yaml",epochs=30, hsv_v=0.3 , translate=0.2,scale=0.3, shear=10,erasing=0.10,  batch=8, imgsz=640, project='runs/train', name='AUG3_food_detection')
# results = model.train(data="/home/aojwang/data/y1_dataset2/y1.yaml",epochs=50, hsv_v=0.3 , translate=0.2,scale=0.3, shear=10,erasing=0.10,  batch=8, imgsz=640, project='runs/train', name='AUG3_food_detection') #50 epochs
results = model.train(data="/home/aojwang/data/yolo_dataset/yolo.yaml",epochs=50, hsv_v=0.3 , translate=0.2,scale=0.3, shear=10,erasing=0.10,  batch=4, imgsz=640, project='runs/train', name='AUG3_food_detection') #50 epochs
#  brightness hsv_v , random translation: translation translate=0.3, image resize: scale=0.4 , X-Y skew: shear=45, random erasing: erasing=0.4
# Out:
# New https://pypi.org/project/ultralytics/8.3.158 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.69 🚀 Python-3.10.12 torch-2.5.1+cu124 CUDA:0 (NVIDIA A10G, 22836MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/home/aojwang/data/yolo_dataset/yolo.yaml, epochs=50, time=None, patience=100, batch=4, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=runs/train, name=AUG3_food_detection4, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.3, degrees=0.0, translate=0.2, scale=0.3, shear=10, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.1, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/train/AUG3_food_detection4
# Overriding model.yaml nc=80 with nc=264
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1   1136296  ultralytics.nn.modules.head.Detect           [264, [64, 128, 256]]
# Model summary: 225 layers, 3,395,832 parameters, 3,395,816 gradients, 10.0 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/train/AUG3_food_detection4', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /opt/dlami/nvme/aojwang/yolo_dataset/train/labels.cache... 9652 images, 640 backgrounds, 0 corrupt: 100%|██████████|
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /opt/dlami/nvme/aojwang/yolo_dataset/val/labels.cache... 2758 images, 188 backgrounds, 0 corrupt: 100%|██████████| 2758
# Plotting labels to runs/train/AUG3_food_detection4/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=3.7e-05, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/AUG3_food_detection4
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         1G       1.72      5.706      1.957         14        640: 100%|██████████| 2413/2413 [07:44<00:00,  5.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 345/345 [01:08<00:00,  5.0
#                    all       2758       4142    0.00257       0.12     0.0047    0.00251
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50     0.948G      1.593      5.152      1.866         11        640: 100%|██████████| 2413/2413 [06:11<00:00,  6.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 345/345 [02:11<00:00,  2.6
#                    all       2758       4142      0.603     0.0302     0.0179     0.0106
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50     0.927G      1.575      4.786      1.842         15        640: 100%|██████████| 2413/2413 [05:32<00:00,  7.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 345/345 [01:38<00:00,  3.4
#                    all       2758       4142      0.575     0.0568     0.0398     0.0251
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
iB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/home/aojwang/data/yolo_dataset/yolo.yaml, epochs=100, time=None, patience=100, batch=8, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=runs/train, name=food_detection, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/train/food_detection
# Overriding model.yaml nc=80 with nc=264
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1   1136296  ultralytics.nn.modules.head.Detect           [264, [64, 128, 256]]
# Model summary: 225 layers, 3,395,832 parameters, 3,395,816 gradients, 10.0 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/train/food_detection', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /opt/dlami/nvme/aojwang/yolo_dataset/train/labels.cache... 9652 images, 640 backgrounds, 0 corrupt: 100%|██████████|
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /opt/dlami/nvme/aojwang/yolo_dataset/val/labels.cache... 2758 images, 188 backgrounds, 0 corrupt: 100%|██████████| 2758
# Plotting labels to runs/train/food_detection/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Exception in thread Thread-75 (_pin_memory_loop):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/torch/utils/data/_utils/pin_memory.py", line 59, in _pin_memory_loop
#     do_one_step()
#   File "/opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/torch/utils/data/_utils/pin_memory.py", line 35, in do_one_step
#     r = in_queue.get(timeout=MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/torch/multiprocessing/reductions.py", line 541, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.10/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.10/multiprocessing/resource_sharer.py", line 86, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 509, in Client
#     deliver_challenge(c, authkey)
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 740, in deliver_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 4
#       2 model = YOLO("yolov8n.pt")
#       3 # yolo model trained without augmented images
# ----> 4 results = model.train(data="/home/aojwang/data/yolo_dataset/yolo.yaml",epochs=100, batch=8, imgsz=640, project='runs/train', name='food_detection')
#
# File /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/ultralytics/engine/model.py:806, in Model.train(self, trainer, **kwargs)
#     803     self.model = self.trainer.model
#     805 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 806 self.trainer.train()
#     807 # Update model and cfg after training
#     808 if RANK in {-1, 0}:
#
# File /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/ultralytics/engine/trainer.py:207, in BaseTrainer.train(self)
#     204         ddp_cleanup(self, str(file))
#     206 else:
# --> 207     self._do_train(world_size)
#
# File /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/ultralytics/engine/trainer.py:330, in BaseTrainer._do_train(self, world_size)
#     328 self.epoch_time_start = time.time()
#     329 self.train_time_start = time.time()
# --> 330 self.run_callbacks("on_train_start")
#     331 LOGGER.info(
#     332     f"Image sizes {self.args.imgsz} train, {self.args.imgsz} val\n"
#     333     f"Using {self.train_loader.num_workers * (world_size or 1)} dataloader workers\n"
#     334     f"Logging results to {colorstr('bold', self.save_dir)}\n"
#     335     f"Starting training for " + (f"{self.args.time} hours..." if self.args.time else f"{self.epochs} epochs...")
#     336 )
#     337 if self.args.close_mosaic:
#
# File /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/ultralytics/engine/trainer.py:168, in BaseTrainer.run_callbacks(self, event)
#     166 """Run all existing callbacks associated with a particular event."""
#     167 for callback in self.callbacks.get(event, []):
# --> 168     callback(self)
#
# File /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/ultralytics/utils/callbacks/tensorboard.py:83, in on_train_start(trainer)
#      81 """Log TensorBoard graph."""
#      82 if WRITER:
# ---> 83     _log_tensorboard_graph(trainer)
#
# File /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/ultralytics/utils/callbacks/tensorboard.py:48, in _log_tensorboard_graph(trainer)
#      46 try:
#      47     trainer.model.eval()  # place in .eval() mode to avoid BatchNorm statistics changes
# ---> 48     WRITER.add_graph(torch.jit.trace(de_parallel(trainer.model), im, strict=False), [])
#      49     LOGGER.info(f"{PREFIX}model graph visualization added ✅")
#      50     return
#
# File /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/torch/jit/_trace.py:1002, in trace(func, example_inputs, optimize, check_trace, check_inputs, check_tolerance, strict, _force_outplace, _module_class, _compilation_unit, example_kwarg_inputs, _store_inputs)
#     989     warnings.warn(
#     990         "`optimize` is deprecated and has no effect. "
#     991         "Use `with torch.jit.optimized_execution()` instead",
#     992         FutureWarning,
#     993         stacklevel=2,
#     994     )
#     996 from torch._utils_internal import (
#     997     check_if_torch_exportable,
#     998     log_torch_jit_trace_exportability,
#     999     log_torchscript_usage,
#    1000 )
# -> 1002 traced_func = _trace_impl(
#    1003     func,
#    1004     example_inputs,
#    1005     optimize,
#    1006     check_trace,
#    1007     check_inputs,
#    1008     check_tolerance,
#    1009     strict,
#    1010     _force_outplace,
#    1011     _module_class,
#    1012     _compilation_unit,
#    1013     example_kwarg_inputs,
#    1014     _store_inputs,
#    1015 )
#    1016 log_torchscript_usage("trace", model_id=_get_model_id(traced_func))
#    1018 if check_if_torch_exportable():
#
# File /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/torch/jit/_trace.py:698, in _trace_impl(func, example_inputs, optimize, check_trace, check_inputs, check_tolerance, strict, _force_outplace, _module_class, _compilation_unit, example_kwarg_inputs, _store_inputs)
#     696         else:
#     697             raise RuntimeError("example_kwarg_inputs should be a dict")
# --> 698     return trace_module(
#     699         func,
#     700         {"forward": example_inputs},
#     701         None,
#     702         check_trace,
#     703         wrap_check_inputs(check_inputs),
#     704         check_tolerance,
#     705         strict,
#     706         _force_outplace,
#     707         _module_class,
#     708         example_inputs_is_kwarg=isinstance(example_kwarg_inputs, dict),
#     709         _store_inputs=_store_inputs,
#     710     )
#     711 if (
#     712     hasattr(func, "__self__")
#     713     and isinstance(func.__self__, torch.nn.Module)
#     714     and func.__name__ == "forward"
#     715 ):
#     716     if example_inputs is None:
#
# File /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/torch/jit/_trace.py:1306, in trace_module(mod, inputs, optimize, check_trace, check_inputs, check_tolerance, strict, _force_outplace, _module_class, _compilation_unit, example_inputs_is_kwarg, _store_inputs)
#    1294                 _check_trace(
#    1295                     check_inputs,
#    1296                     func,
#    (...)
#    1303                     example_inputs_is_kwarg=example_inputs_is_kwarg,
#    1304                 )
#    1305             else:
# -> 1306                 _check_trace(
#    1307                     [inputs],
#    1308                     func,
#    1309                     check_trace_method,
#    1310                     check_tolerance,
#    1311                     strict,
#    1312                     _force_outplace,
#    1313                     True,
#    1314                     _module_class,
#    1315                     example_inputs_is_kwarg=example_inputs_is_kwarg,
#    1316                 )
#    1317 finally:
#    1318     torch.jit._trace._trace_module_map = old_module_map
#
# File /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/torch/jit/_trace.py:341, in _check_trace(check_inputs, func, traced_func, check_tolerance, strict, force_outplace, is_trace_module, _module_class, example_inputs_is_kwarg)
#     339 for name, data in inputs.items():
#     340     copied_dict[name] = _clone_inputs(data)
# --> 341 check_mod = torch.jit.trace_module(
#     342     getattr(func, "__self__", func),
#     343     copied_dict,
#     344     check_trace=False,
#     345     strict=strict,
#     346     _force_outplace=force_outplace,
#     347     _module_class=_module_class,
#     348     _compilation_unit=torch._C.CompilationUnit(),
#     349     example_inputs_is_kwarg=example_inputs_is_kwarg,
#     350     _store_inputs=False,
#     351 )
#     352 check_mod_func = check_mod._c._get_method(traced_func.name)
#     353 inputs = inputs[traced_func.name]
#
# File /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/torch/jit/_trace.py:1243, in trace_module(mod, inputs, optimize, check_trace, check_inputs, check_tolerance, strict, _force_outplace, _module_class, _compilation_unit, example_inputs_is_kwarg, _store_inputs)
#    1240 torch.jit._trace._trace_module_map = trace_module_map
#    1241 register_submods(mod, "__module")
# -> 1243 module = make_module(mod, _module_class, _compilation_unit)
#    1245 for method_name, example_inputs in inputs.items():
#    1246     if method_name == "forward":
#    1247         # "forward" is a special case because we need to trace
#    1248         # `Module.__call__`, which sets up some extra tracing, but uses
#    1249         # argument names of the real `Module.forward` method.
#
# File /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/torch/jit/_trace.py:631, in make_module(mod, _module_class, _compilation_unit)
#     629 if _module_class is None:
#     630     _module_class = TopLevelTracedModule
# --> 631 return _module_class(mod, _compilation_unit=_compilation_unit)
#
# File /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/torch/jit/_trace.py:1393, in TracedModule.__init__(self, orig, id_set, _compilation_unit)
#    1391     if submodule is None:
#    1392         continue
# -> 1393     tmp_module._modules[name] = make_module(
#    1394         submodule, TracedModule, _compilation_unit=None
#    1395     )
#    1397 script_module = torch.jit._recursive.create_script_module(
#    1398     tmp_module, lambda module: (), share_types=False, is_tracing=True
#    1399 )
#    1401 self.__dict__["_name"] = type(orig).__name__
#
# File /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/torch/jit/_trace.py:631, in make_module(mod, _module_class, _compilation_unit)
#     629 if _module_class is None:
#     630     _module_class = TopLevelTracedModule
# --> 631 return _module_class(mod, _compilation_unit=_compilation_unit)
#
# File /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/torch/jit/_trace.py:1393, in TracedModule.__init__(self, orig, id_set, _compilation_unit)
#    1391     if submodule is None:
#    1392         continue
# -> 1393     tmp_module._modules[name] = make_module(
#    1394         submodule, TracedModule, _compilation_unit=None
#    1395     )
#    1397 script_module = torch.jit._recursive.create_script_module(
#    1398     tmp_module, lambda module: (), share_types=False, is_tracing=True
#    1399 )
#    1401 self.__dict__["_name"] = type(orig).__name__
#
# File /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/torch/jit/_trace.py:631, in make_module(mod, _module_class, _compilation_unit)
#     629 if _module_class is None:
#     630     _module_class = TopLevelTracedModule
# --> 631 return _module_class(mod, _compilation_unit=_compilation_unit)
#
# File /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/torch/jit/_trace.py:1366, in TracedModule.__init__(self, orig, id_set, _compilation_unit)
#    1361         raise ValueError(
#    1362             "TracedModules don't support parameter sharing between modules"
#    1363         )
#    1364     id_set.add(param)
# -> 1366 tmp_module.training = orig.training
#    1368 for name, param in orig._parameters.items():
#    1369     if param is not None:
#
# File /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1995, in Module.__setattr__(self, name, value)
#    1993 else:
#    1994     buffers = self.__dict__.get("_buffers")
# -> 1995     if isinstance(value, Buffer) or buffers is not None and name in buffers:
#    1996         if value is not None and not isinstance(value, torch.Tensor):
#    1997             raise TypeError(
#    1998                 f"cannot assign '{torch.typename(value)}' as buffer '{name}' "
#    1999                 "(torch.nn.Buffer, torch.Tensor or None expected)"
#    2000             )
#
# File /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/torch/nn/parameter.py:216, in _BufferMeta.__instancecheck__(self, instance)
#     214 class _BufferMeta(torch._C._TensorMeta):
#     215     # Make `isinstance(t, Buffer)` return True for custom tensor instances that have the _is_buffer flag.
# --> 216     def __instancecheck__(self, instance):
#     217         if self is Buffer:
#     218             if isinstance(instance, torch.Tensor) and getattr(
#     219                 instance, "_is_buffer", False
#     220             ):
#
# KeyboardInterrupt:

# %%
from ultralytics import YOLO
import os
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Load the trained YOLO model
# model = YOLO("/home/aojwang/data/model/model/CarboAI/runs/train/AUG3_food_detection2/weights/best.pt")
model = YOLO("/home/aojwang/data/model/model/CarboAI/runs/train/yolo11_food_detection_improved9/weights/best.pt")

# Load all image paths (case-insensitive JPG/JPEG)
image_paths = glob('/home/aojwang/data/y1_dataset2/val/images/*')
image_paths = [p for p in image_paths if p.lower().endswith(('.jpg'))]

actual_classes = [] # np.zeros(len(image_paths))
predicted_classes =  []  # np.zeros(len(image_paths))
misactual_classes = []
mispredicted_classes = []

for im_index, img_path in enumerate(image_paths):
    # Check for corresponding label
    label_path = img_path.replace('images', 'labels')
    label_path = os.path.splitext(label_path)[0] + '.txt'
    
    if not os.path.exists(label_path):
        continue  # skip image if no label
    actual_class = []
    with open(label_path, 'r') as f:
        lines = f.readlines()
        targets = [int(line.split()[0]) for line in lines]
        actual_class.extend(targets)
        #print("actual", targets)
    
    results = model(img_path, verbose=False)
    predicted_class = []
    for r in results:
        if len(r.boxes) > 0:
            preds = r.boxes.cls.cpu().numpy().astype(int)
            predicted_class.extend( [x.item() for x in preds])
    #print("predicted", predicted_class)
    for item in actual_class:
        if item in predicted_class:
            actual_classes.append(item)
            predicted_classes.append(item)
        else:
            actual_classes.append(item)
            predicted_classes.append(0)
    for item in predicted_class:
        if item not in actual_class:
            mispredicted_classes.append(item)
            misactual_classes.append(0)
    #break
    
# Scatter plot
plt.figure(figsize=(6, 6))
plt.scatter(actual_classes, predicted_classes, alpha=0.5, color='purple', label='Predictions')
plt.scatter(misactual_classes, mispredicted_classes, alpha=0.5, color='red', label='mispredictions')

# Dotted y = x reference line
max_val = max(max(actual_classes), max(predicted_classes))
min_val = min(min(actual_classes), min(predicted_classes))
plt.plot([min_val, max_val], [min_val, max_val], 'k--', label='Perfect Prediction')

# Labels and title
plt.xlabel("Actual Class Labels")
plt.ylabel("Predicted Class Labels")
plt.title("Actual vs Predicted Class Labels")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Accuracy (already calculated)
accuracy = np.mean(np.array(actual_classes) == np.array(predicted_classes))

# Precision, Recall, F1
precision = precision_score(actual_classes, predicted_classes, average='macro', zero_division=0)
recall = recall_score(actual_classes, predicted_classes, average='macro', zero_division=0)
f1 = f1_score(actual_classes, predicted_classes, average='macro', zero_division=0)

print(f"Accuracy: {accuracy * 100:.2f}%")
print(f"Precision: {precision * 100:.2f}%")
print(f"Recall: {recall * 100:.2f}%")
print(f"F1 Score: {f1 * 100:.2f}%")
# Out:
# Accuracy: 98.02%
# Precision: 97.75%
# Recall: 96.26%
# F1 Score: 96.64%

# %% [markdown]
# # Validate yolo model

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/home/aojwang/data/model/model/CarboAI/runs/train/yolo11_food_detection_improved6/weights/best.pt")

# Validate the model
metrics = model.val(data='/home/aojwang/data/y1_dataset2/v1.yaml', project='runs/val', save_json=True)
print(metrics.box.map)  # mAP50-95
print(metrics.box.map50)  # mAP50
print(metrics.box.map75)  # mAP75
print(metrics.box.maps)  # list of mAP50-95 for each category
# Out:
# Ultralytics 8.3.69 🚀 Python-3.10.12 torch-2.5.1+cu124 CUDA:0 (NVIDIA A10G, 22836MiB)
# YOLO11n summary (fused): 238 layers, 2,697,280 parameters, 0 gradients, 6.9 GFLOPs
# val: Scanning /opt/dlami/nvme/aojwang/y1_dataset2/val/labels.cache... 718 images, 50 backgrounds, 0 corrupt: 100%|██████████| 718/718
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████|
#      0.76698       0.768     0.61136     0.76698]

# %% [markdown]
# # Visualize annotations

# %%
import os
import random
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Load YOLO model
model = YOLO("/home/aojwang/data/model/model/CarboAI/runs/train/yolo11_food_detection_improved6/weights/best.pt")

# Path to image directory
image_dir = "/home/aojwang/data/MergeDataset/images"
all_images = [os.path.join(image_dir, f) for f in os.listdir(image_dir) if f.lower().endswith((".jpg", ".JPG",))]

# Select 9 random images
sample_images = random.sample(all_images, 9)

# Run batched inference
results = model(sample_images, verbose=False)

# Create 3x3 grid for displaying results
fig, axes = plt.subplots(3, 3, figsize=(12, 12))
axes = axes.flatten()

# Show each result directly using .plot()
for i, result in enumerate(results):
    annotated_img = result.plot()  
    axes[i].imshow(annotated_img[..., ::-1])
    axes[i].axis('off')
    axes[i].set_title(f"Prediction {i+1}")

plt.tight_layout()
plt.show()

# %% [markdown]
# #  Load YOLOv8 for Food Recognition & Extraction

# %%
import torch
import cv2
import numpy as np
import pandas as pd
import torchvision.transforms as transforms
from torchvision import models
import torch.nn as nn
from ultralytics import YOLO
from fuzzywuzzy import process

# --- Model + Data Setup ---
YOLO_MODEL_PATH = "/home/aojwang/data/model/model/CarboAI/runs/train/yolo11_food_detection_improved6/weights/best.pt"
CSV_FILE = "/home/aojwang/data/MergeDataset/csv_files/found_merged.csv"
MODEL_SAVE_PATH = "/home/aojwang/data/model/model/CarboAI/food_weight_model.pth"

# Load YOLOv8
yolo_model = YOLO(YOLO_MODEL_PATH)

# Load and clean CSV
df = pd.read_csv(CSV_FILE)
df.columns = df.columns.str.strip().str.replace("\n", " ").str.replace("  ", " ")
df["LABELS"] = df["LABELS"].astype(str).str.lower().str.strip()


# --- Define Weight Estimation Model ---
class WeightEstimationModel(nn.Module):
    """
    A regression model that uses pretrained MobileNetV3 features and additional
    geometric and intensity-based features to estimate food weight from images.
    Args:
        feature_dim (int): Number of additional handcrafted features to concatenate.
    """
    def __init__(self, feature_dim=3):
        super(WeightEstimationModel, self).__init__()
        self.mobilenet = models.mobilenet_v3_large(weights=models.MobileNet_V3_Large_Weights.IMAGENET1K_V1)
        self.mobilenet.classifier = nn.Identity()
        self.fc = nn.Sequential(
            nn.Linear(960 + feature_dim, 512),
            nn.ReLU(),
            nn.Linear(512, 128),
            nn.ReLU(),
            nn.Linear(128, 1),
            nn.ReLU()
        )

    def forward(self, image, additional_features):
        """
        Forward pass through the model.

        Args:
            image (torch.Tensor): Preprocessed image tensor [1, 3, 224, 224].
            additional_features (torch.Tensor): Handcrafted features tensor [1, feature_dim].

        Returns:
            torch.Tensor: Estimated food weight [1].
        """
        image_features = self.mobilenet(image)
        combined = torch.cat((image_features, additional_features), dim=1)
        return self.fc(combined)


#--- Load model to device ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
weight_model = WeightEstimationModel().to(device)


# --- Get food carbohydrate content ---
def get_food_carbs(image_path, detected_label):
    """
    Uses fuzzy matching to retrieve the carbohydrate content from the CSV file.

    Args:
        image_path (str): Full path to the image.
        detected_label (str): Detected label from YOLO.

    Returns:
        float or None: Corresponding carbohydrate content in grams or None if not found.
    """
    detected_label = detected_label.lower().strip()
    image_data = df[df["ospath"] == image_path]

    if image_data.empty:
        print(f"⚠️ No CSV match for image {image_path}")
        return None

    all_labels = image_data["LABELS"].dropna().unique()
    best_match, score = process.extractOne(detected_label, all_labels)

    if score < 80:
        print(f"⚠️ Poor match for {detected_label} in {image_path} (Score: {score})")
        return None

    carb_col = df.columns[3]
    carbs = image_data.loc[image_data["LABELS"] == best_match, carb_col]

    if not carbs.empty:
        print(f"✅ Matched {detected_label} -> {best_match} ({float(carbs.iloc[0])}g carbs)")
        return float(carbs.iloc[0])

    return None


#--- Preprocess image for training/ prediction ---
def preprocess_image(image_path, use_ground_truth=True):
    """
    1. Detects food using YOLOv8
    2. Extracts bounding box features (area, aspect ratio, pixel intensity)
    3. Crops detected food item for MobileNetV3
    4. Retrieves the corresponding carbohydrate weight from the CSV
    
    Args:
        image_path (str): Path to the input image.
        use_ground_truth : bool
            If True, retrieves true weight from CSV for each detected item. Use for training.
            If False, skips weight lookup. Use for inference.

    Returns:
        list: Tuples of (label, image_tensor, additional_features, weight or None).
    """
    print(f"\n📷 Processing: {image_path}")
    image = cv2.imread(image_path)
    if image is None:
        print(f"❌ Error: Cannot read {image_path}")
        return []

    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = yolo_model(image, verbose=False)
    detections = results[0].boxes
    if len(detections) == 0:
        print("⚠️ No food detected.")
        return []

    img_h, img_w = image.shape[:2]
    image_area = img_h * img_w

    food_data = []
    for box in detections:
        x1, y1, x2, y2 = map(int, box.xyxy[0].tolist())
        label = yolo_model.names[int(box.cls[0].item())]
        print(f"🧭 Detected: {label}")
        cropped = image[y1:y2, x1:x2]
        if cropped.shape[0] == 0 or cropped.shape[1] == 0:
            print(f"⚠️ Invalid crop for {label}")
            continue

        h, w = cropped.shape[:2]

        # Handcrafted features
        area = h * w
        aspect_ratio = w / (h + 1e-5)
        intensity = np.mean(cropped)

        # 🔄 Normalization
        norm_area = area / image_area
        norm_aspect_ratio = aspect_ratio
        norm_intensity = intensity / 255.0

        # Image preprocessing for CNN
        transform = transforms.Compose([
            transforms.ToPILImage(),
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])
        img_tensor = transform(cropped).unsqueeze(0).to(device)

        # Final feature tensor
        features = torch.tensor(
            [norm_area, norm_aspect_ratio, norm_intensity],
            dtype=torch.float32
        ).unsqueeze(0).to(device)

        # Carb label
        weight = get_food_carbs(image_path, label) if use_ground_truth else None
        food_data.append((label, img_tensor, features, weight))

    return food_data


# --- Training Function ---
def train_model(epochs=10):
    """
    Trains the WeightEstimationModel using YOLO detections and CSV-labeled weights.

    Args:
        epochs (int): Number of training epochs.
    """
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(weight_model.parameters(), lr=0.001)
    dataset = df["ospath"].dropna().unique()

    epoch_losses = [] 

    for epoch in range(epochs):
        weight_model.train()
        total_loss = 0.0
        count = 0
        print(f"\n📚 Epoch {epoch+1}/{epochs}")

        for path in dataset:
            food_items = preprocess_image(path, use_ground_truth=True)
            for label, img, feat, true_weight in food_items:
                if true_weight is None:
                    continue

                y = torch.tensor([true_weight], dtype=torch.float32).to(device)
                img, feat = img.to(device), feat.to(device)

                optimizer.zero_grad()
                pred = weight_model(img, feat)
                loss = criterion(pred, y)
                loss.backward()
                optimizer.step()

                total_loss += loss.item()
                count += 1

        avg_loss = total_loss / count if count else 0
        epoch_losses.append((epoch + 1, avg_loss))
        print(f"📘 Epoch {epoch+1} — Avg Loss: {avg_loss:.4f}")

    # Final summary table
    print("\n📊 Epoch Loss Summary:")
    print("{:<10} {:<15}".format("Epoch", "Average Loss"))
    print("-" * 25)
    for ep, loss in epoch_losses:
        print("{:<10} {:<15.4f}".format(ep, loss))

    torch.save(weight_model.state_dict(), MODEL_SAVE_PATH)
    print("\n✅ Training complete. Model saved!")


# --- Prediction Function ---
def predict_food_carbs(image_path):
    """
    Loads the trained model and predicts carbohydrate weights for all food items in an image.
    Also retrieves the actual carbohydrate weight from the CSV for comparison.

    Args:
        image_path (str): Path to the input image.
    """
    # Load trained model weights
    weight_model.load_state_dict(torch.load(MODEL_SAVE_PATH, map_location=device))
    weight_model.eval()

    # Run inference pipeline (without retrieving weight for loss)
    food_items = preprocess_image(image_path, use_ground_truth=False)

    print(f"\n🔍 Predictions for {image_path}:\n")

    for label, img, feat, _ in food_items:
        # Predict weight
        with torch.no_grad():
            predicted_weight = weight_model(img, feat).item()

        # Get ground truth weight using fuzzy match
        actual_carbs = get_food_carbs(image_path, label)

        if actual_carbs is not None:
            print(f"🍽️ {label:<20} → Predicted: {predicted_weight:.2f}g carbs | Actual: {actual_carbs:.2f}g carbs")

        else:
            print(f"🍽️ {label:<20} → Predicted: {predicted_weight:.2f}g carbs | Actual: Not Found ❌")
# Out:
# /opt/dlami/nvme/aojwang/torchenv/lib/python3.10/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
train_model(epochs=5)
# Out:
# 📚 Epoch 1/5
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1ArrowrootEggBroccoli.jpg
# 🧭 Detected: Mincemeat
# ⚠️ Poor match for mincemeat in /home/aojwang/data/MergeDataset/images/1ArrowrootEggBroccoli.jpg (Score: 21)
# 🧭 Detected: Spinach Cooked
# ⚠️ Poor match for spinach cooked in /home/aojwang/data/MergeDataset/images/1ArrowrootEggBroccoli.jpg (Score: 25)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1BreadBaconSpinach.jpg
# 🧭 Detected: Sukumawiki
# ⚠️ Poor match for sukumawiki in /home/aojwang/data/MergeDataset/images/1BreadBaconSpinach.jpg (Score: 18)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1BreadSausageSpinach.jpg
# 🧭 Detected: Thabai
# ⚠️ Poor match for thabai in /home/aojwang/data/MergeDataset/images/1BreadSausageSpinach.jpg (Score: 28)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1CassavaEggSukuma.jpg
# 🧭 Detected: Boiled Egg
# ⚠️ Poor match for boiled egg in /home/aojwang/data/MergeDataset/images/1CassavaEggSukuma.jpg (Score: 71)
# 🧭 Detected: Sukumawiki
# ⚠️ Poor match for sukumawiki in /home/aojwang/data/MergeDataset/images/1CassavaEggSukuma.jpg (Score: 25)
# 🧭 Detected: Boiled Egg
# ⚠️ Poor match for boiled egg in /home/aojwang/data/MergeDataset/images/1CassavaEggSukuma.jpg (Score: 71)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1MaizeEggCarrot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2MaizeEggCarrot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1PastaChickenBroccoli.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2PastaChickenBroccoli.jpg
# 🧭 Detected: Asparagus
# ⚠️ Poor match for asparagus in /home/aojwang/data/MergeDataset/images/2PastaChickenBroccoli.jpg (Score: 54)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3PastaChickenBroccoli.jpg
# 🧭 Detected: Asparagus
# ⚠️ Poor match for asparagus in /home/aojwang/data/MergeDataset/images/3PastaChickenBroccoli.jpg (Score: 54)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1PastaChickenCarrot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2PastaChickenCarrot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1PastaChickenZucchiniCarrot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1PotatoPorkCarrot.jpg
# 🧭 Detected: White Ugali
# ⚠️ Poor match for white ugali in /home/aojwang/data/MergeDataset/images/1PotatoPorkCarrot.jpg (Score: 25)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2PotatoPorkCarrot.jpg
# 🧭 Detected: Red Cabbage
# ⚠️ Poor match for red cabbage in /home/aojwang/data/MergeDataset/images/2PotatoPorkCarrot.jpg (Score: 31)
# 🧭 Detected: White Ugali
# ⚠️ Poor match for white ugali in /home/aojwang/data/MergeDataset/images/2PotatoPorkCarrot.jpg (Score: 25)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3PotatoPorkCarrot.jpg
# 🧭 Detected: White Ugali
# ⚠️ Poor match for white ugali in /home/aojwang/data/MergeDataset/images/3PotatoPorkCarrot.jpg (Score: 25)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1RiceBChickenCabbage.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2RiceBChickenCabbage.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3RiceBChickenCabbage.jpg
# 🧭 Detected: Saget
# ⚠️ Poor match for saget in /home/aojwang/data/MergeDataset/images/3RiceBChickenCabbage.jpg (Score: 18)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Ri
jpg (Score: 26)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Yam.jpg
# 🧭 Detected: Boiled Egg
# ⚠️ Poor match for boiled egg in /home/aojwang/data/MergeDataset/images/3Yam.jpg (Score: 0)
#
# 📷 Processing:  CONTENT (g)"
# ❌ Error: Cannot read  CONTENT (g)"
#
# 📷 Processing: CONTENT  (kcal)"
# ❌ Error: Cannot read CONTENT  (kcal)"
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1ChapatiPeasSukuma.jpg
# [ WARN:0@444551.623] global loadsave.cpp:268 findDecoder imread_(' CONTENT (g)"'): can't open/read file: check file path/integrity
# [ WARN:0@444551.623] global loadsave.cpp:268 findDecoder imread_('CONTENT  (kcal)"'): can't open/read file: check file path/integrity
# 🧭 Detected: Sukumawiki
# ⚠️ Poor match for sukumawiki in /home/aojwang/data/MergeDataset/images/1ChapatiPeasSukuma.jpg (Score: 17)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1ChapatiSukuma.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1MaizeZucciniCarrot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1PastaBroccoli.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2PastaBroccoli.jpg
# 🧭 Detected: Asparagus
# ⚠️ Poor match for asparagus in /home/aojwang/data/MergeDataset/images/2PastaBroccoli.jpg (Score: 12)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3PastaBroccoli.jpg
# 🧭 Detected: Asparagus
# ⚠️ Poor match for asparagus in /home/aojwang/data/MergeDataset/images/3PastaBroccoli.jpg (Score: 12)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1PastaCarrot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2PastaCarrot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1SpaghettiCarrotZuccini.jpg
# 🧭 Detected: French beans
# ⚠️ Poor match for french beans in /home/aojwang/data/MergeDataset/images/1SpaghettiCarrotZuccini.jpg (Score: 30)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1PastaSukumaMushrooms.jpg
# 🧭 Detected: Sukumawiki
# ⚠️ Poor match for sukumawiki in /home/aojwang/data/MergeDataset/images/1PastaSukumaMushrooms.jpg (Score: 27)
# 🧭 Detected: Blueberry
# ⚠️ Poor match for blueberry in /home/aojwang/data/MergeDataset/images/1PastaSukumaMushrooms.jpg (Score: 0)
# 🧭 Detected: Cucumber
# ⚠️ Poor match for cucumber in /home/aojwang/data/MergeDataset/images/1PastaSukumaMushrooms.jpg (Score: 0)
# 🧭 Detected: French beans
# ⚠️ Poor match for french beans in /home/aojwang/data/MergeDataset/images/1PastaSukumaMushrooms.jpg (Score: 45)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2PastaSukumaMushrooms.jpg
# 🧭 Detected: Sukumawiki
# ⚠️ Poor match for sukumawiki in /home/aojwang/data/MergeDataset/images/2PastaSukumaMushrooms.jpg (Score: 27)
# 🧭 Detected: French beans
# ⚠️ Poor match for french beans in /home/aojwang/data/MergeDataset/images/2PastaSukumaMushrooms.jpg (Score: 45)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1PotatoAvocadoLettuce.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1RiceBBroccoliCarrot.jpg
# 🧭 Detected: Spinach Cooked
# ⚠️ Poor match for spinach cooked in /home/aojwang/data/MergeDataset/images/1RiceBBroccoliCarrot.jpg (Score: 39)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2RiceBBroccoliCarrot.jpg
# 🧭 Detected: Spinach Cooked
# ⚠️ Poor match for spinach cooked in /home/aojwang/data/MergeDataset/images/2RiceBBroccoliCarrot.jpg (Score: 39)
# 🧭 Detected: Sukumawiki
# ⚠️ Poor match for sukumawiki in /home/aojwang/data/MergeDataset/images/2RiceBBroccoliCarrot.jpg (Score: 22)
# 🧭 Detected: Ndengu
# ⚠️ Poor match for ndengu in /home/aojwang/data/MergeDataset/images/2RiceBBroccoliCarrot.jpg (Score: 30)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3RiceBBroccoliCarrot.jpg
# 🧭 Detected: Black Beans
# ⚠️ Poor match for black beans in /home/aojwang/data/MergeDataset/images/3RiceBBroccoliCarrot.jpg (Score: 36)
# 🧭 Detected: Spinach Cooked
# ⚠️ Poor match for spinach cooked in /home/aojwang/data/MergeDataset/images/3RiceBBroccoliCarrot.jpg (Score: 39)
# 🧭 Detected: Sukumawiki
# ⚠️ Poor match for sukumawiki in /home/aojwang/data/MergeDataset/images/3RiceBBroccoliCarrot.jpg (Score: 22)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1RiceWBroccoliCarrot.jpg
# 🧭 Detected: Black Beans
# ⚠️ Poor match for black beans in /home/aojwang/data/MergeDataset/images/1RiceWBroccoliCarrot.jpg (Score: 36)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2RiceWBroccoliCarrot.jpg
# 🧭 Detected: French beans
# ⚠️ Poor match for french beans in /home/aojwang/data/MergeDataset/images/2RiceWBroccoliCarrot.jpg (Score: 39)
# 🧭 Detected: Zucchini
# ⚠️ Poor match for zucchini in /home/aojwang/data/MergeDataset/images/2RiceWBroccoliCarrot.jpg (Score: 34)
# 🧭 Detected: Black Beans
# ⚠️ Poor match for black beans in /home/aojwang/data/MergeDataset/images/2RiceWBroccoliCarrot.jpg (Score: 36)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3RiceWBroccoliCarrot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1RiceWFrenchB.jpg
# 🧭 Detected: French beans
# ⚠️ Poor match for french beans in /home/aojwang/data/MergeDataset/images/1RiceWFrenchB.jpg (Score: 39)
# 🧭 Detected: White Rice Boiled
# ✅ Matched white rice boiled -> white rice boiled (42.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2RiceWFrenchB.jpg
# 🧭 Detected: White Rice Boiled
# ✅ Matched white rice boiled -> white rice boiled (85.0g carbs)
# 🧭 Detected: French beans
# ⚠️ Poor match for french beans in /home/aojwang/data/MergeDataset/images/2RiceWFrenchB.jpg (Score: 39)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3RiceWFrenchB.jpg
# 🧭 Detected: French beans
# ⚠️ Poor match for french beans in /home/aojwang/data/MergeDataset/images/3RiceWFrenchB.jpg (Score: 39)
# 🧭 Detected: Sesame Seeds
# ⚠️ Poor match for sesame seeds in /home/aojwang/data/MergeDataset/images/3RiceWFrenchB.jpg (Score: 34)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1RiceDenguTerere.jpg
# 🧭 Detected: White Rice Boiled
# ✅ Matched white rice boiled -> white rice boiled (85.0g carbs)
# 🧭 Detected: White Rice Boiled
# ✅ Matched white rice boiled -> white rice boiled (85.0g carbs)
# 🧭 Detected: Terere
# ⚠️ Poor match for terere in /home/aojwang/data/MergeDataset/images/1RiceDenguTerere.jpg (Score: 45)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1SamosaVege.jpg
# 🧭 Detected: Cucumber
# ⚠️ Poor match for cucumber in /home/aojwang/data/MergeDataset/images/1SamosaVege.jpg (Score: 0)
# 🧭 Detected: Zucchini
# ⚠️ Poor match for zucchini in /home/aojwang/data/MergeDataset/images/1SamosaVege.jpg (Score: 36)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2SamosaVege.jpg
# 🧭 Detected: Eggplant
# ⚠️ Poor match for eggplant in /home/aojwang/data/MergeDataset/images/2SamosaVege.jpg (Score: 60)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Bacon.jpg
# 🧭 Detected: Poppy Seeds
# ⚠️ Poor match for poppy seeds in /home/aojwang/data/MergeDataset/images/1Bacon.jpg (Score: 18)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Bacon.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Bacon.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1BeefFry.jpg
# 🧭 Detected: Red Cabbage Cooked
# ⚠️ Poor match for red cabbage cooked in /home/aojwang/data/MergeDataset/images/1BeefFry.jpg (Score: 34)
# 🧭 Detected: Red Cabbage
# ⚠️ Poor match for red cabbage in /home/aojwang/data/MergeDataset/images/1BeefFry.jpg (Score: 40)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2BeefFry.jpg
# 🧭 Detected: Red Cabbage Cooked
# ⚠️ Poor match for red cabbage cooked in /home/aojwang/data/MergeDataset/images/2BeefFry.jpg (Score: 34)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3BeefFry.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1BeefRoast.jpg
# 🧭 Detected: Red Cabbage Cooked
# ⚠️ Poor match for red cabbage cooked in /home/aojwang/data/MergeDataset/images/1BeefRoast.jpg (Score: 36)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2BeefRoast.jpg
# 🧭 Detected: Red Cabbage
# ⚠️ Poor match for red cabbage in /home/aojwang/data/MergeDataset/images/2BeefRoast.jpg (Score: 36)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3BeefRoast.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Ham.jpg
# 🧭 Detected: Poppy Seeds
# ⚠️ Poor match for poppy seeds in /home/aojwang/data/MergeDataset/images/1Ham.jpg (Score: 0)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Ham.jpg
# 🧭 Detected: Biscuit
# ⚠️ Poor match for biscuit in /home/aojwang/data/MergeDataset/images/2Ham.jpg (Score: 0)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Ham.jpg
# 🧭 Detected: Biscuit
# ⚠️ Poor match for biscuit in /home/aojwang/data/MergeDataset/images/3Ham.jpg (Score: 0)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1ChickenDrumsticks.jpg
# 🧭 Detected: Biscuit
# ⚠️ Poor match for biscuit in /home/aojwang/data/MergeDataset/images/1ChickenDrumsticks.jpg (Score: 30)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2ChickenDrumsticks.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3ChickenDrumsticks.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1ChickenMakhni.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2ChickenMakhni.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3ChickenMakhni.jpg
# 🧭 Detected: Sorghum Porridge
# ⚠️ Poor match for sorghum porridge in /home/aojwang/data/MergeDataset/images/3ChickenMakhni.jpg (Score: 26)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1ChickenRoast.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2ChickenRoast.jpg
# 🧭 Detected: Red Cabbage
# ⚠️ Poor match for red cabbage in /home/aojwang/data/MergeDataset/images/2ChickenRoast.jpg (Score: 26)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3ChickenRoast.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1EggBoiled.jpg
# 🧭 Detected: Boiled Egg
# ✅ Matched boiled egg -> boiled egg (1.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2EggBoiled.jpg
# 🧭 Detected: Boiled Egg
# ✅ Matched boiled egg -> boiled egg (1.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3EggBoiled.jpg
# 🧭 Detected: Boiled Egg
# ✅ Matched boiled egg -> boiled egg (2.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1EggFried.jpg
# 🧭 Detected: Arrowroots
# ⚠️ Poor match for arrowroots in /home/aojwang/data/MergeDataset/images/1EggFried.jpg (Score: 12)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1EggOmelettePlain.jpg
# 🧭 Detected: Spinach Cooked
# ⚠️ Poor match for spinach cooked in /home/aojwang/data/MergeDataset/images/1EggOmelettePlain.jpg (Score: 30)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1EggScrambled.jpg
# 🧭 Detected: Black Beans
# ⚠️ Poor match for black beans in /home/aojwang/data/MergeDataset/images/1EggScrambled.jpg (Score: 40)
# 🧭 Detected: Rosecoco
# ⚠️ Poor match for rosecoco in /home/aojwang/data/MergeDataset/images/1EggScrambled.jpg (Score: 23)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Fish.jpg
# 🧭 Detected: Fish Fry
# ✅ Matched fish fry -> fish fry (0.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Fish.jpg
# 🧭 Detected: Fish Fry
# ✅ Matched fish fry -> fish fry (0.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Fish.jpg
# 🧭 Detected: Fish Fry
# ✅ Matched fish fry -> fish fry (0.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1FishFillet.jpg
# 🧭 Detected: Custard Apple
# ⚠️ Poor match for custard apple in /home/aojwang/data/MergeDataset/images/1FishFillet.jpg (Score: 33)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2FishFillet.jpg
# 🧭 Detected: Custard Apple
# ⚠️ Poor match for custard apple in /home/aojwang/data/MergeDataset/images/2FishFillet.jpg (Score: 33)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3FishFillet.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1LambStew.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2LambStew.jpg
# 🧭 Detected: Thabai
# ⚠️ Poor match for thabai in /home/aojwang/data/MergeDataset/images/2LambStew.jpg (Score: 20)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3LambStew.jpg
# 🧭 Detected: Thabai
# ⚠️ Poor match for thabai in /home/aojwang/data/MergeDataset/images/3LambStew.jpg (Score: 20)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Liver.jpg
# 🧭 Detected: Matumbo Fry
# ⚠️ Poor match for matumbo fry in /home/aojwang/data/MergeDataset/images/1Liver.jpg (Score: 48)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Liver.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Liver.jpg
# 🧭 Detected: Fish Fry
# ⚠️ Poor match for fish fry in /home/aojwang/data/MergeDataset/images/3Liver.jpg (Score: 59)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1MatumboFried.jpg
# 🧭 Detected: Blueberry
# ⚠️ Poor match for blueberry in /home/aojwang/data/MergeDataset/images/1MatumboFried.jpg (Score: 30)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2MatumboFried.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3MatumboFried.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Meatballs.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Meatballs.jpg
# 🧭 Detected: Maize Porridge
# ⚠️ Poor match for maize porridge in /home/aojwang/data/MergeDataset/images/2Meatballs.jpg (Score: 20)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Meatballs.jpg
# 🧭 Detected: Maize Porridge
# ⚠️ Poor match for maize porridge in /home/aojwang/data/MergeDataset/images/3Meatballs.jpg (Score: 20)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1MeatMinced.jpg
# 🧭 Detected: Poppy Seeds
# ⚠️ Poor match for poppy seeds in /home/aojwang/data/MergeDataset/images/1MeatMinced.jpg (Score: 20)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2MeatMinced.jpg
# 🧭 Detected: Poppy Seeds
# ⚠️ Poor match for poppy seeds in /home/aojwang/data/MergeDataset/images/2MeatMinced.jpg (Score: 20)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3MeatMinced.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Omena.jpg
# 🧭 Detected: Poppy Seeds
# ⚠️ Poor match for poppy seeds in /home/aojwang/data/MergeDataset/images/1Omena.jpg (Score: 25)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Omena.jpg
# 🧭 Detected: Poppy Seeds
# ⚠️ Poor match for poppy seeds in /home/aojwang/data/MergeDataset/images/2Omena.jpg (Score: 25)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Omena.jpg
# 🧭 Detected: Poppy Seeds
# ⚠️ Poor match for poppy seeds in /home/aojwang/data/MergeDataset/images/3Omena.jpg (Score: 25)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1PorkFried.jpg
# 🧭 Detected: Fish Fry
# ⚠️ Poor match for fish fry in /home/aojwang/data/MergeDataset/images/1PorkFried.jpg (Score: 52)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2PorkFried.jpg
# 🧭 Detected: Matumbo Fry
# ⚠️ Poor match for matumbo fry in /home/aojwang/data/MergeDataset/images/2PorkFried.jpg (Score: 53)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3PorkFried.jpg
# 🧭 Detected: Matumbo Fry
# ⚠️ Poor match for matumbo fry in /home/aojwang/data/MergeDataset/images/3PorkFried.jpg (Score: 53)
# 🧭 Detected: Fish Fry
# ⚠️ Poor match for fish fry in /home/aojwang/data/MergeDataset/images/3PorkFried.jpg (Score: 52)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Sausage.jpg
# 🧭 Detected: Sausage
# ✅ Matched sausage -> sausage (3.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Sausage.jpg
# 🧭 Detected: Sausage
# ✅ Matched sausage -> sausage (9.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Sausage.jpg
# 🧭 Detected: Sausage
# ✅ Matched sausage -> sausage (15.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1SausageBacon.jpg
# 🧭 Detected: Sausage
# ⚠️ Poor match for sausage in /home/aojwang/data/MergeDataset/images/1SausageBacon.jpg (Score: 17)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2SausageBacon.jpg
# 🧭 Detected: Sausage
# ⚠️ Poor match for sausage in /home/aojwang/data/MergeDataset/images/2SausageBacon.jpg (Score: 17)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3SausageBacon.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Asparagus.jpg
# 🧭 Detected: French beans
# ⚠️ Poor match for french beans in /home/aojwang/data/MergeDataset/images/1Asparagus.jpg (Score: 29)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Asparagus.jpg
# 🧭 Detected: French beans
# ⚠️ Poor match for french beans in /home/aojwang/data/MergeDataset/images/2Asparagus.jpg (Score: 29)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Asparagus.jpg
# 🧭 Detected: French beans
# ⚠️ Poor match for french beans in /home/aojwang/data/MergeDataset/images/3Asparagus.jpg (Score: 29)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Beetroot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Beetroot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Beetroot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Butternut.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Butternut.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Butternut.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Broccoli.jpg
# 🧭 Detected: Broccoli
# ✅ Matched broccoli -> broccoli (2.0g carbs)
# 🧭 Detected: Spinach Cooked
# ⚠️ Poor match for spinach cooked in /home/aojwang/data/MergeDataset/images/1Broccoli.jpg (Score: 34)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Broccoli.jpg
# 🧭 Detected: Spinach Cooked
# ⚠️ Poor match for spinach cooked in /home/aojwang/data/MergeDataset/images/2Broccoli.jpg (Score: 34)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Broccoli.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1CabbageRed.jpg
# 🧭 Detected: Red Cabbage
# ✅ Matched red cabbage -> red cabbage cooked (4.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2CabbageRed.jpg
# 🧭 Detected: Red Cabbage
# ✅ Matched red cabbage -> red cabbage cooked (8.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3CabbageRed.jpg
# 🧭 Detected: Red Cabbage
# ✅ Matched red cabbage -> red cabbage cooked (12.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1CabbageGreen.jpg
# 🧭 Detected: Thabai
# ⚠️ Poor match for thabai in /home/aojwang/data/MergeDataset/images/1CabbageGreen.jpg (Score: 45)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2CabbageGreen.jpg
# 🧭 Detected: Thabai
# ⚠️ Poor match for thabai in /home/aojwang/data/MergeDataset/images/2CabbageGreen.jpg (Score: 45)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3CabbageGreen.jpg
# 🧭 Detected: Thabai
# ⚠️ Poor match for thabai in /home/aojwang/data/MergeDataset/images/3CabbageGreen.jpg (Score: 45)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Cabbagesprout.jpg
# 🧭 Detected: Kachumbari
# ⚠️ Poor match for kachumbari in /home/aojwang/data/MergeDataset/images/1Cabbagesprout.jpg (Score: 33)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Cabbagesprout.jpg
# 🧭 Detected: Spinach Cooked
# ⚠️ Poor match for spinach cooked in /home/aojwang/data/MergeDataset/images/2Cabbagesprout.jpg (Score: 34)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Cabbagesprout.jpg
# 🧭 Detected: Spinach Cooked
# ⚠️ Poor match for spinach cooked in /home/aojwang/data/MergeDataset/images/3Cabbagesprout.jpg (Score: 34)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1RedGreenYellowCapsicum.jpg
# 🧭 Detected: Red Cabbage Cucumber Plum Tomato Yellow Bell Pepper Cucumber
# ✅ Matched red cabbage cucumber plum tomato yellow bell pepper cucumber -> red green yellow bell pepper (5.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2RedGreenYellowCapsicum.jpg
# 🧭 Detected: Red Cabbage Cucumber Plum Tomato Yellow Bell Pepper Cucumber
# ✅ Matched red cabbage cucumber plum tomato yellow bell pepper cucumber -> red green yellow bell pepper (6.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Carrot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Carrot.jpg
# 🧭 Detected: Sausage
# ⚠️ Poor match for sausage in /home/aojwang/data/MergeDataset/images/2Carrot.jpg (Score: 15)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Carrot.jpg
# 🧭 Detected: Eggplant
# ⚠️ Poor match for eggplant in /home/aojwang/data/MergeDataset/images/3Carrot.jpg (Score: 29)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Cauliflower.jpg
# 🧭 Detected: Cucumber
# ⚠️ Poor match for cucumber in /home/aojwang/data/MergeDataset/images/1Cauliflower.jpg (Score: 42)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Cauliflower.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Cauliflower.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Cucumber.jpg
# 🧭 Detected: Cucumber
# ✅ Matched cucumber -> cucumber (1.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Cucumber.jpg
# 🧭 Detected: Cucumber
# ✅ Matched cucumber -> cucumber (2.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Cucumber.jpg
# 🧭 Detected: Cucumber
# ✅ Matched cucumber -> cucumber (5.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Eggplant.jpg
# 🧭 Detected: Eggplant
# ✅ Matched eggplant -> eggplant (1.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Eggplant.jpg
# 🧭 Detected: Eggplant
# ✅ Matched eggplant -> eggplant (3.0g carbs)
# 🧭 Detected: Eggplant
# ✅ Matched eggplant -> eggplant (3.0g carbs)
#
# ...
# ✅ Matched white rice boiled -> white rice boiled (2.4g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1747WhiteRiceWhiteChapatiBeefstew.JPG
# 🧭 Detected: Black Beans
# ⚠️ Poor match for black beans in /home/aojwang/data/MergeDataset/images/1747WhiteRiceWhiteChapatiBeefstew.JPG (Score: 36)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1748WhiteRiceWhiteChapatihalfBeefstew.JPG
# 🧭 Detected: Thabai
# ⚠️ Poor match for thabai in /home/aojwang/data/MergeDataset/images/1748WhiteRiceWhiteChapatihalfBeefstew.JPG (Score: 30)
# 🧭 Detected: Blueberry
# ⚠️ Poor match for blueberry in /home/aojwang/data/MergeDataset/images/1748WhiteRiceWhiteChapatihalfBeefstew.JPG (Score: 38)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1749WhiteRiceWhiteChapatiquoertBeefstew.JPG
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1750WhiteRiceWhiteChapatiBeefstew.JPG
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/
# 🧭 Detected: White Ugali
# ⚠️ Poor match for white ugali in /home/aojwang/data/MergeDataset/images/1790FishwetfryBrownUgali1CupSpinach.JPG (Score: 21)
# 📘 Epoch 5 — Avg Loss: 2199.1596
#
# 📊 Epoch Loss Summary:
# Epoch      Average Loss
# -------------------------
# 1          1388.1415
# 2          1925.4860
# 3          2199.1596
# 4          2199.1596
# 5          2199.1596
#
# ✅ Training complete. Model saved!

# %%
preprocess_image("/home/aojwang/data/MergeDataset/images/3DalmakhnilcuminRice.jpg", use_ground_truth=True)
# Out:
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3DalmakhnilcuminRice.jpg
# 🧭 Detected: White Rice Boiled
# ✅ Matched white rice boiled -> white rice boiled (127.0g carbs)
# [('White Rice Boiled',
#   tensor([[[[ 1.1358,  1.1015,  1.0673,  ...,  0.9132,  1.0159,  0.9817],
#             [ 1.0844,  1.1358,  0.9988,  ...,  1.0502,  1.0159,  0.9988],
#             [ 1.0844,  1.0331,  1.0331,  ...,  1.0159,  0.9646,  1.0502],
#             ...,
#             [ 1.3070,  1.1187,  1.0159,  ...,  2.1462,  2.1804,  2.1975],
#             [ 1.3584,  1.3242,  1.1358,  ...,  2.1804,  2.1975,  2.2147],
#             [ 1.5639,  1.4440,  1.2043,  ...,  2.1975,  2.2147,  2.2147]],
#
#            [[ 1.1681,  1.1331,  1.1506,  ...,  1.0630,  1.1506,  1.1331],
#             [ 1.1681,  1.2031,  1.1331,  ...,  1.2206,  1.1681,  1.1681],
#             [ 1.2206,  1.1681,  1.2031,  ...,  1.1856,  1.1155,  1.2031],
#             ...,
#             [ 1.4132,  1.2206,  1.1155,  ...,  2.3235,  2.3585,  2.3761],
#             [ 1.4657,  1.4307,  1.2381,  ...,  2.3410,  2.3761,  2.3936],
#             [ 1.6933,  1.5707,  1.3256,  ...,  2.3761,  2.3936,  2.3936]],
#
#            [[-0.9330, -0.9330, -0.9330,  ..., -1.0201, -0.8458, -0.9330],
#             [-0.9504, -0.8458, -0.9853,  ..., -0.9156, -0.8807, -0.9330],
#             [-0.9504, -0.8807, -0.9678,  ..., -0.9853, -0.9504, -0.9156],
#             ...,
#             [ 1.7511,  1.5594,  1.5071,  ...,  2.5354,  2.5703,  2.5877],
#             [ 1.8034,  1.7685,  1.6291,  ...,  2.5529,  2.5877,  2.6051],
#             [ 1.9777,  1.8383,  1.6640,  ...,  2.5877,  2.6051,  2.6051]]]], device='cuda:0'),
#   tensor([[0.1266, 1.9821, 0.7681]], device='cuda:0'),
#   127.0)]

# %%
predict_food_carbs("/home/aojwang/data/MergeDataset/images/3DalmakhnilcuminRice.jpg")
# Out:
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3DalmakhnilcuminRice.jpg
# 🧭 Detected: Poppy Seeds
# 🧭 Detected: White Rice Boiled
# 🧭 Detected: Sesame Seeds
#
# 🔍 Predictions for /home/aojwang/data/MergeDataset/images/3DalmakhnilcuminRice.jpg:
#
# ⚠️ Poor match for poppy seeds in /home/aojwang/data/MergeDataset/images/3DalmakhnilcuminRice.jpg (Score: 32)
# 🍽️ Poppy Seeds          → Predicted: 0.00g carbs | Actual: Not Found ❌
# ✅ Matched white rice boiled -> white rice boiled (127.0g carbs)
# 🍽️ White Rice Boiled    → Predicted: 0.00g carbs | Actual: 127.00g carbs
# ⚠️ Poor match for sesame seeds in /home/aojwang/data/MergeDataset/images/3DalmakhnilcuminRice.jpg (Score: 34)
# 🍽️ Sesame Seeds         → Predicted: 0.00g carbs | Actual: Not Found ❌

# %%
import matplotlib.pyplot as plt

# Load model and set to eval
weight_model.load_state_dict(torch.load(MODEL_SAVE_PATH, map_location=device))
weight_model.eval()

# Collect all unique image paths
image_paths = df["ospath"].dropna().unique()

actual_weights = []
predicted_weights = []

# Process each image
for image_path in image_paths:
    food_items = preprocess_image(image_path, use_ground_truth=False)
    
    for label, img, feat, _ in food_items:
        # Predict weight
        with torch.no_grad():
            pred = weight_model(img, feat).item()

        actual = get_food_carbs(image_path, label)
        
        if actual is not None:
            predicted_weights.append(pred)
            actual_weights.append(actual)

# Scatter Plot
plt.figure(figsize=(7, 7))
plt.scatter(actual_weights, predicted_weights, color='purple', alpha=0.6, label="Predictions")

# Reference Line (Perfect Prediction)
min_val = min(min(actual_weights), min(predicted_weights))
max_val = max(max(actual_weights), max(predicted_weights))
plt.plot([min_val, max_val], [min_val, max_val], 'k--', label="Perfect Prediction")

plt.xlabel("Actual Carbohydrate Content (g)")
plt.ylabel("Predicted Carbohydrate Content (g)")
plt.title("Actual vs Predicted Carbohydrate Content")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1ArrowrootEggBroccoli.jpg
# 🧭 Detected: Mincemeat
# 🧭 Detected: Spinach Cooked
# ⚠️ Poor match for mincemeat in /home/aojwang/data/MergeDataset/images/1ArrowrootEggBroccoli.jpg (Score: 21)
# ⚠️ Poor match for spinach cooked in /home/aojwang/data/MergeDataset/images/1ArrowrootEggBroccoli.jpg (Score: 25)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1BreadBaconSpinach.jpg
# 🧭 Detected: Sukumawiki
# ⚠️ Poor match for sukumawiki in /home/aojwang/data/MergeDataset/images/1BreadBaconSpinach.jpg (Score: 18)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1BreadSausageSpinach.jpg
# 🧭 Detected: Thabai
# ⚠️ Poor match for thabai in /home/aojwang/data/MergeDataset/images/1BreadSausageSpinach.jpg (Score: 28)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1CassavaEggSukuma.jpg
# 🧭 Detected: Boiled Egg
# 🧭 Detected: Sukumawiki
# 🧭 Detected: Boiled Egg
# ⚠️ Poor match for boiled egg in /home/aojwang/data/MergeDataset/images/1CassavaEggSukuma.jpg (Score: 71)
# ⚠️ Poor match for sukumawiki in /home/aojwang/data/MergeDataset/images/1CassavaEggSukuma.jpg (Score: 25)
# ⚠️ Poor match for boiled egg in /home/aojwang/data/MergeDataset/images/1CassavaEggSukuma.jpg (Score: 71)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1MaizeEggCarrot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2MaizeEggCarrot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1PastaChickenBroccoli.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2PastaChickenBroccoli.jpg
# 🧭 Detected: Asparagus
# ⚠️ Poor match for asparagus in /home/aojwang/data/MergeDataset/images/2PastaChickenBroccoli.jpg (Score: 54)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3PastaChickenBroccoli.jpg
# 🧭 Detected: Asparagus
# ⚠️ Poor match for asparagus in /home/aojwang/data/MergeDataset/images/3PastaChickenBroccoli.jpg (Score: 54)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1PastaChickenCarrot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2PastaChickenCarrot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1PastaChickenZucchiniCarrot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1PotatoPorkCarrot.jpg
# 🧭 Detected: White Ugali
# ⚠️ Poor match for white ugali in /home/aojwang/data/MergeDataset/images/1PotatoPorkCarrot.jpg (Score: 25)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2PotatoPorkCarrot.jpg
# 🧭 Detected: Red Cabbage
# 🧭 Detected: White Ugali
# ⚠️ Poor match for red cabbage in /home/aojwang/data/MergeDataset/images/2PotatoPorkCarrot.jpg (Score: 31)
# ⚠️ Poor match for white ugali in /home/aojwang/data/MergeDataset/images/2PotatoPorkCarrot.jpg (Score: 25)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3PotatoPorkCarrot.jpg
# 🧭 Detected: White Ugali
# ⚠️ Poor match for white ugali in /home/aojwang/data/MergeDataset/images/3PotatoPorkCarrot.jpg (Score: 25)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1RiceBChickenCabbage.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2RiceBChickenCabbage.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3RiceBChickenCabbage.jpg
# 🧭 Detected: Saget
# ⚠️ Poor match for saget in /home/aojwang/data/MergeDataset/images/3RiceBChickenCabbage.jpg (Score: 18)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1RiceBLiverVeg.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3RiceBLiverVeg.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2RiceBLiverVeg.jpg
# 🧭 Detected: Sesame Seeds
# ⚠️ Poor match for sesame seeds in /home/aojwang/data/MergeDataset/images/2RiceBLiverVeg.jpg (Score: 28)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Ri
jpg
# 🧭 Detected: White Ugali
# ✅ Matched white ugali -> white ugali (48.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3UgaliWFishSpinach.jpg
# 🧭 Detected: Boiled Egg
# 🧭 Detected: White Ugali
# 🧭 Detected: Spinach Cooked
# ⚠️ Poor match for boiled egg in /home/aojwang/data/MergeDataset/images/3UgaliWFishSpinach.jpg (Score: 19)
# ✅ Matched white ugali -> white ugali (90.0g carbs)
# ⚠️ Poor match for spinach cooked in /home/aojwang/data/MergeDataset/images/3UgaliWFishSpinach.jpg (Score: 16)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1UgaliWOmenaVegies.jpg
# 🧭 Detected: White Ugali
# 🧭 Detected: Thabai
# ✅ Matched white ugali -> white ugali (48.0g carbs)
# ⚠️ Poor match for thabai in /home/aojwang/data/MergeDataset/images/1UgaliWOmenaVegies.jpg (Score: 35)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2UgaliWOmenaVegies.jpg
# 🧭 Detected: White Ugali
# 🧭 Detected: Maize Porridge
# ✅ Matched white ugali -> white ugali (90.0g carbs)
# ⚠️ Poor match for maize porridge in /home/aojwang/data/MergeDataset/images/2UgaliWOmenaVegies.jpg (Score: 32)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3UgaliWOmenaVegies.jpg
# 🧭 Detected: Maize Porridge
# 🧭 Detected: White Ugali
# 🧭 Detected: Maize Porridge
# ⚠️ Poor match for maize porridge in /home/aojwang/data/MergeDataset/images/3UgaliWOmenaVegies.jpg (Score: 32)
# ✅ Matched white ugali -> white ugali (131.0g carbs)
# ⚠️ Poor match for maize porridge in /home/aojwang/data/MergeDataset/images/3UgaliWOmenaVegies.jpg (Score: 32)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Arrowroots.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Arrowroots.jpg
# 🧭 Detected: Biscuit
# ⚠️ Poor match for biscuit in /home/aojwang/data/MergeDataset/images/2Arrowroots.jpg (Score: 12)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Arrowroots.jpg
# 🧭 Detected: Brown Ugali
# 🧭 Detected: Biscuit
# ⚠️ Poor match for brown ugali in /home/aojwang/data/MergeDataset/images/3Arrowroots.jpg (Score: 29)
# ⚠️ Poor match for biscuit in /home/aojwang/data/MergeDataset/images/3Arrowroots.jpg (Score: 12)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1BananaBoiled.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2BananaBoiled.jpg
# 🧭 Detected: Cucumber
# 🧭 Detected: Cucumber
# ⚠️ Poor match for cucumber in /home/aojwang/data/MergeDataset/images/2BananaBoiled.jpg (Score: 22)
# ⚠️ Poor match for cucumber in /home/aojwang/data/MergeDataset/images/2BananaBoiled.jpg (Score: 22)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3BananaBoiled.jpg
# 🧭 Detected: Cucumber
# ⚠️ Poor match for cucumber in /home/aojwang/data/MergeDataset/images/3BananaBoiled.jpg (Score: 22)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1MatokeMashed.jpg
# 🧭 Detected: Spinach Cooked
# ⚠️ Poor match for spinach cooked in /home/aojwang/data/MergeDataset/images/1MatokeMashed.jpg (Score: 33)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2MatokeMashed.jpg
# 🧭 Detected: Spinach Cooked
# ⚠️ Poor match for spinach cooked in /home/aojwang/data/MergeDataset/images/2MatokeMashed.jpg (Score: 33)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3MatokeMashed.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Biscuit.jpg
# 🧭 Detected: Lemon
# ⚠️ Poor match for lemon in /home/aojwang/data/MergeDataset/images/1Biscuit.jpg (Score: 0)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Biscuit.jpg
# 🧭 Detected: Boiled Egg
# ⚠️ Poor match for boiled egg in /home/aojwang/data/MergeDataset/images/2Biscuit.jpg (Score: 24)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Biscuit.jpg
# 🧭 Detected: Biscuit
# ✅ Matched biscuit -> biscuit (71.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1BBread.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2BBread.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3BBread.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1WBread.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2WBread.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3WBread.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1WMBBread.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2WMBBread.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3WMBBread.jpg
# 🧭 Detected: Arrowroots
# ⚠️ Poor match for arrowroots in /home/aojwang/data/MergeDataset/images/3WMBBread.jpg (Score: 20)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1BreadSpreadAvocado.jpg
# 🧭 Detected: White Bread Avocado Spread
# ✅ Matched white bread avocado spread -> white bread avocado spread (16.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1WBreadButter.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1BreadSpreadHoney.jpg
# 🧭 Detected: White Bread Avocado Spread
# ✅ Matched white bread avocado spread -> white bread honey spread (32.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1BreadSpreadJam.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1BreadSpreadMarg.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1BreadSpreadPeanutB.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Cassava.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Cassava.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Cassava.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Cornflakes.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Cornflakes.jpg
# 🧭 Detected: Red Cabbage
# 🧭 Detected: French beans
# ⚠️ Poor match for red cabbage in /home/aojwang/data/MergeDataset/images/2Cornflakes.jpg (Score: 28)
# ⚠️ Poor match for french beans in /home/aojwang/data/MergeDataset/images/
jpg (Score: 30)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1PotatoSweet.jpg
# 🧭 Detected: Passion
# ⚠️ Poor match for passion in /home/aojwang/data/MergeDataset/images/1PotatoSweet.jpg (Score: 41)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2PotatoSweet.jpg
# 🧭 Detected: Passion
# ⚠️ Poor match for passion in /home/aojwang/data/MergeDataset/images/2PotatoSweet.jpg (Score: 41)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3PotatoSweet.jpg
# 🧭 Detected: Passion
# 🧭 Detected: Avocado
# ⚠️ Poor match for passion in /home/aojwang/data/MergeDataset/images/3PotatoSweet.jpg (Score: 41)
# ⚠️ Poor match for avocado in /home/aojwang/data/MergeDataset/images/3PotatoSweet.jpg (Score: 36)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1WUgali.jpg
# 🧭 Detected: Poppy Seeds
# ⚠️ Poor match for poppy seeds in /home/aojwang/data/MergeDataset/images/1WUgali.jpg (Score: 17)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2WUgali.jpg
# 🧭 Detected: White Ugali
# ✅ Matched white ugali -> white ugali (90.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3WUgali.jpg
# 🧭 Detected: White Ugali
# ✅ Matched white ugali -> white ugali (131.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1BUgali.jpg
# 🧭 Detected: Poppy Seeds
# ⚠️ Poor match for poppy seeds in /home/aojwang/data/MergeDataset/images/1BUgali.jpg (Score: 18)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2BUgali.jpg
# 🧭 Detected: Biscuit
# ⚠️ Poor match for biscuit in /home/aojwang/data/MergeDataset/images/2BUgali.jpg (Score: 26)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Yam.jpg
# 🧭 Detected: Boiled Egg
# ⚠️ Poor match for boiled egg in /home/aojwang/data/MergeDataset/images/3Yam.jpg (Score: 0)
#
# 📷 Processing:  CONTENT (g)"
# ❌ Error: Cannot read  CONTENT (g)"
#
# 📷 Processing: CONTENT  (kcal)"
# ❌ Error: Cannot read CONTENT  (kcal)"
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1ChapatiPeasSukuma.jpg
# 🧭 Detected: Sukumawiki
# ⚠️ Poor match for sukumawiki in /home/aojwang/data/MergeDataset/images/1ChapatiPeasSukuma.jpg (Score: 17)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1ChapatiSukuma.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1MaizeZucciniCarrot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1PastaBroccoli.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2PastaBroccoli.jpg
# 🧭 Detected: Asparagus
# [ WARN:0@485723.525] global loadsave.cpp:268 findDecoder imread_(' CONTENT (g)"'): can't open/read file: check file path/integrity
# [ WARN:0@485723.526] global loadsave.cpp:268 findDecoder imread_('CONTENT  (kcal)"'): can't open/read file: check file path/integrity
# ⚠️ Poor match for asparagus in /home/aojwang/data/MergeDataset/images/2PastaBroccoli.jpg (Score: 12)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3PastaBroccoli.jpg
# 🧭 Detected: Asparagus
# ⚠️ Poor match for asparagus in /home/aojwang/data/MergeDataset/images/3PastaBroccoli.jpg (Score: 12)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1PastaCarrot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2PastaCarrot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1SpaghettiCarrotZuccini.jpg
# 🧭 Detected: French beans
# ⚠️ Poor match for french beans in /home/aojwang/data/MergeDataset/images/1SpaghettiCarrotZuccini.jpg (Score: 30)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1PastaSukumaMushrooms.jpg
# 🧭 Detected: Sukumawiki
# 🧭 Detected: Blueberry
# 🧭 Detected: Cucumber
# 🧭 Detected: French beans
# ⚠️ Poor match for sukumawiki in /home/aojwang/data/MergeDataset/images/1PastaSukumaMushrooms.jpg (Score: 27)
# ⚠️ Poor match for blueberry in /home/aojwang/data/MergeDataset/images/1PastaSukumaMushrooms.jpg (Score: 0)
# ⚠️ Poor match for cucumber in /home/aojwang/data/MergeDataset/images/1PastaSukumaMushrooms.jpg (Score: 0)
# ⚠️ Poor match for french beans in /home/aojwang/data/MergeDataset/images/1PastaSukumaMushrooms.jpg (Score: 45)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2PastaSukumaMushrooms.jpg
# 🧭 Detected: Sukumawiki
# 🧭 Detected: French beans
# ⚠️ Poor match for sukumawiki in /home/aojwang/data/MergeDataset/images/2PastaSukumaMushrooms.jpg (Score: 27)
# ⚠️ Poor match for french beans in /home/aojwang/data/MergeDataset/images/2PastaSukumaMushrooms.jpg (Score: 45)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1PotatoAvocadoLettuce.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1RiceBBroccoliCarrot.jpg
# 🧭 Detected: Spinach Cooked
# ⚠️ Poor match for spinach cooked in /home/aojwang/data/MergeDataset/images/1RiceBBroccoliCarrot.jpg (Score: 39)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2RiceBBroccoliCarrot.jpg
# 🧭 Detected: Spinach Cooked
# 🧭 Detected: Sukumawiki
# 🧭 Detected: Ndengu
# ⚠️ Poor match for spinach cooked in /home/aojwang/data/MergeDataset/images/2RiceBBroccoliCarrot.jpg (Score: 39)
# ⚠️ Poor match for sukumawiki in /home/aojwang/data/MergeDataset/images/2RiceBBroccoliCarrot.jpg (Score: 22)
# ⚠️ Poor match for ndengu in /home/aojwang/data/MergeDataset/images/2RiceBBroccoliCarrot.jpg (Score: 30)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3RiceBBroccoliCarrot.jpg
# 🧭 Detected: Black Beans
# 🧭 Detected: Spinach Cooked
# 🧭 Detected: Sukumawiki
# ⚠️ Poor match for black beans in /home/aojwang/data/MergeDataset/images/3RiceBBroccoliCarrot.jpg (Score: 36)
# ⚠️ Poor match for spinach cooked in /home/aojwang/data/MergeDataset/images/3RiceBBroccoliCarrot.jpg (Score: 39)
# ⚠️ Poor match for sukumawiki in /home/aojwang/data/MergeDataset/images/3RiceBBroccoliCarrot.jpg (Score: 22)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1RiceWBroccoliCarrot.jpg
# 🧭 Detected: Black Beans
# ⚠️ Poor match for black beans in /home/aojwang/data/MergeDataset/images/1RiceWBroccoliCarrot.jpg (Score: 36)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2RiceWBroccoliCarrot.jpg
# 🧭 Detected: French beans
# 🧭 Detected: Zucchini
# 🧭 Detected: Black Beans
# ⚠️ Poor match for french beans in /home/aojwang/data/MergeDataset/images/2RiceWBroccoliCarrot.jpg (Score: 39)
# ⚠️ Poor match for zucchini in /home/aojwang/data/MergeDataset/images/2RiceWBroccoliCarrot.jpg (Score: 34)
# ⚠️ Poor match for black beans in /home/aojwang/data/MergeDataset/images/2RiceWBroccoliCarrot.jpg (Score: 36)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3RiceWBroccoliCarrot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1RiceWFrenchB.jpg
# 🧭 Detected: French beans
# 🧭 Detected: White Rice Boiled
# ⚠️ Poor match for french beans in /home/aojwang/data/MergeDataset/images/1RiceWFrenchB.jpg (Score: 39)
# ✅ Matched white rice boiled -> white rice boiled (42.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2RiceWFrenchB.jpg
# 🧭 Detected: White Rice Boiled
# 🧭 Detected: French beans
# ✅ Matched white rice boiled -> white rice boiled (85.0g carbs)
# ⚠️ Poor match for french beans in /home/aojwang/data/MergeDataset/images/2RiceWFrenchB.jpg (Score: 39)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3RiceWFrenchB.jpg
# 🧭 Detected: French beans
# 🧭 Detected: Sesame Seeds
# ⚠️ Poor match for french beans in /home/aojwang/data/MergeDataset/images/3RiceWFrenchB.jpg (Score: 39)
# ⚠️ Poor match for sesame seeds in /home/aojwang/data/MergeDataset/images/3RiceWFrenchB.jpg (Score: 34)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1RiceDenguTerere.jpg
# 🧭 Detected: White Rice Boiled
# 🧭 Detected: White Rice Boiled
# 🧭 Detected: Terere
# ✅ Matched white rice boiled -> white rice boiled (85.0g carbs)
# ✅ Matched white rice boiled -> white rice boiled (85.0g carbs)
# ⚠️ Poor match for terere in /home/aojwang/data/MergeDataset/images/1RiceDenguTerere.jpg (Score: 45)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1SamosaVege.jpg
# 🧭 Detected: Cucumber
# 🧭 Detected: Zucchini
# ⚠️ Poor match for cucumber in /home/aojwang/data/MergeDataset/images/1SamosaVege.jpg (Score: 0)
# ⚠️ Poor match for zucchini in /home/aojwang/data/MergeDataset/images/1SamosaVege.jpg (Score: 36)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2SamosaVege.jpg
# 🧭 Detected: Eggplant
# ⚠️ Poor match for eggplant in /home/aojwang/data/MergeDataset/images/2SamosaVege.jpg (Score: 60)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Bacon.jpg
# 🧭 Detected: Poppy Seeds
# ⚠️ Poor match for poppy seeds in /home/aojwang/data/MergeDataset/images/1Bacon.jpg (Score: 18)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Bacon.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Bacon.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1BeefFry.jpg
# 🧭 Detected: Red Cabbage Cooked
# 🧭 Detected: Red Cabbage
# ⚠️ Poor match for red cabbage cooked in /home/aojwang/data/MergeDataset/images/1BeefFry.jpg (Score: 34)
# ⚠️ Poor match for red cabbage in /home/aojwang/data/MergeDataset/images/1BeefFry.jpg (Score: 40)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2BeefFry.jpg
# 🧭 Detected: Red Cabbage Cooked
# ⚠️ Poor match for red cabbage cooked in /home/aojwang/data/MergeDataset/images/2BeefFry.jpg (Score: 34)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3BeefFry.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1BeefRoast.jpg
# 🧭 Detected: Red Cabbage Cooked
# ⚠️ Poor match for red cabbage cooked in /home/aojwang/data/MergeDataset/images/1BeefRoast.jpg (Score: 36)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2BeefRoast.jpg
# 🧭 Detected: Red Cabbage
# ⚠️ Poor match for red cabbage in /home/aojwang/data/MergeDataset/images/2BeefRoast.jpg (Score: 36)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3BeefRoast.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Ham.jpg
# 🧭 Detected: Poppy Seeds
# ⚠️ Poor match for poppy seeds in /home/aojwang/data/MergeDataset/images/1Ham.jpg (Score: 0)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Ham.jpg
# 🧭 Detected: Biscuit
# ⚠️ Poor match for biscuit in /home/aojwang/data/MergeDataset/images/2Ham.jpg (Score: 0)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Ham.jpg
# 🧭 Detected: Biscuit
# ⚠️ Poor match for biscuit in /home/aojwang/data/MergeDataset/images/3Ham.jpg (Score: 0)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1ChickenDrumsticks.jpg
# 🧭 Detected: Biscuit
# ⚠️ Poor match for biscuit in /home/aojwang/data/MergeDataset/images/1ChickenDrumsticks.jpg (Score: 30)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2ChickenDrumsticks.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3ChickenDrumsticks.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1ChickenMakhni.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2ChickenMakhni.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3ChickenMakhni.jpg
# 🧭 Detected: Sorghum Porridge
# ⚠️ Poor match for sorghum porridge in /home/aojwang/data/MergeDataset/images/3ChickenMakhni.jpg (Score: 26)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1ChickenRoast.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2ChickenRoast.jpg
# 🧭 Detected: Red Cabbage
# ⚠️ Poor match for red cabbage in /home/aojwang/data/MergeDataset/images/2ChickenRoast.jpg (Score: 26)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3ChickenRoast.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1EggBoiled.jpg
# 🧭 Detected: Boiled Egg
# ✅ Matched boiled egg -> boiled egg (1.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2EggBoiled.jpg
# 🧭 Detected: Boiled Egg
# ✅ Matched boiled egg -> boiled egg (1.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3EggBoiled.jpg
# 🧭 Detected: Boiled Egg
# ✅ Matched boiled egg -> boiled egg (2.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1EggFried.jpg
# 🧭 Detected: Arrowroots
# ⚠️ Poor match for arrowroots in /home/aojwang/data/MergeDataset/images/1EggFried.jpg (Score: 12)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1EggOmelettePlain.jpg
# 🧭 Detected: Spinach Cooked
# ⚠️ Poor match for spinach cooked in /home/aojwang/data/MergeDataset/images/1EggOmelettePlain.jpg (Score: 30)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1EggScrambled.jpg
# 🧭 Detected: Black Beans
# 🧭 Detected: Rosecoco
# ⚠️ Poor match for black beans in /home/aojwang/data/MergeDataset/images/1EggScrambled.jpg (Score: 40)
# ⚠️ Poor match for rosecoco in /home/aojwang/data/MergeDataset/images/1EggScrambled.jpg (Score: 23)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Fish.jpg
# 🧭 Detected: Fish Fry
# ✅ Matched fish fry -> fish fry (0.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Fish.jpg
# 🧭 Detected: Fish Fry
# ✅ Matched fish fry -> fish fry (0.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Fish.jpg
# 🧭 Detected: Fish Fry
# ✅ Matched fish fry -> fish fry (0.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1FishFillet.jpg
# 🧭 Detected: Custard Apple
# ⚠️ Poor match for custard apple in /home/aojwang/data/MergeDataset/images/1FishFillet.jpg (Score: 33)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2FishFillet.jpg
# 🧭 Detected: Custard Apple
# ⚠️ Poor match for custard apple in /home/aojwang/data/MergeDataset/images/2FishFillet.jpg (Score: 33)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3FishFillet.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1LambStew.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2LambStew.jpg
# 🧭 Detected: Thabai
# ⚠️ Poor match for thabai in /home/aojwang/data/MergeDataset/images/2LambStew.jpg (Score: 20)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3LambStew.jpg
# 🧭 Detected: Thabai
# ⚠️ Poor match for thabai in /home/aojwang/data/MergeDataset/images/3LambStew.jpg (Score: 20)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Liver.jpg
# 🧭 Detected: Matumbo Fry
# ⚠️ Poor match for matumbo fry in /home/aojwang/data/MergeDataset/images/1Liver.jpg (Score: 48)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Liver.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Liver.jpg
# 🧭 Detected: Fish Fry
# ⚠️ Poor match for fish fry in /home/aojwang/data/MergeDataset/images/3Liver.jpg (Score: 59)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1MatumboFried.jpg
# 🧭 Detected: Blueberry
# ⚠️ Poor match for blueberry in /home/aojwang/data/MergeDataset/images/1MatumboFried.jpg (Score: 30)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2MatumboFried.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3MatumboFried.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Meatballs.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Meatballs.jpg
# 🧭 Detected: Maize Porridge
# ⚠️ Poor match for maize porridge in /home/aojwang/data/MergeDataset/images/2Meatballs.jpg (Score: 20)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Meatballs.jpg
# 🧭 Detected: Maize Porridge
# ⚠️ Poor match for maize porridge in /home/aojwang/data/MergeDataset/images/3Meatballs.jpg (Score: 20)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1MeatMinced.jpg
# 🧭 Detected: Poppy Seeds
# ⚠️ Poor match for poppy seeds in /home/aojwang/data/MergeDataset/images/
0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2RedGreenYellowCapsicum.jpg
# 🧭 Detected: Red Cabbage Cucumber Plum Tomato Yellow Bell Pepper Cucumber
# ✅ Matched red cabbage cucumber plum tomato yellow bell pepper cucumber -> red green yellow bell pepper (6.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Carrot.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Carrot.jpg
# 🧭 Detected: Sausage
# ⚠️ Poor match for sausage in /home/aojwang/data/MergeDataset/images/2Carrot.jpg (Score: 15)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Carrot.jpg
# 🧭 Detected: Eggplant
# ⚠️ Poor match for eggplant in /home/aojwang/data/MergeDataset/images/3Carrot.jpg (Score: 29)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Cauliflower.jpg
# 🧭 Detected: Cucumber
# ⚠️ Poor match for cucumber in /home/aojwang/data/MergeDataset/images/1Cauliflower.jpg (Score: 42)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Cauliflower.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Cauliflower.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Cucumber.jpg
# 🧭 Detected: Cucumber
# ✅ Matched cucumber -> cucumber (1.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Cucumber.jpg
# 🧭 Detected: Cucumber
# ✅ Matched cucumber -> cucumber (2.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Cucumber.jpg
# 🧭 Detected: Cucumber
# ✅ Matched cucumber -> cucumber (5.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Eggplant.jpg
# 🧭 Detected: Eggplant
# ✅ Matched eggplant -> eggplant (1.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Eggplant.jpg
# 🧭 Detected: Eggplant
# 🧭 Detected: Eggplant
# ✅ Matched eggplant -> eggplant (3.0g carbs)
# ✅ Matched eggplant -> eggplant (3.0g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/3Eggplant.jpg
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1Kitojo.jpg
# 🧭 Detected: Thabai
# ⚠️ Poor match for thabai in /home/aojwang/data/MergeDataset/images/1Kitojo.jpg (Score: 17)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/2Kitojo.jpg
# 🧭 Detected: Thabai
# ...
# 🧭 Detected: Murenda
# 🧭 Detected: White Rice Boiled
# ⚠️ Poor match for blueberry in /home/aojwang/data/MergeDataset/images/1746WhiteRiceWhiteChapatiquoterBeefstew.JPG (Score: 38)
# ⚠️ Poor match for murenda in /home/aojwang/data/MergeDataset/images/1746WhiteRiceWhiteChapatiquoterBeefstew.JPG (Score: 28)
# ✅ Matched white rice boiled -> white rice boiled (2.4g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1747WhiteRiceWhiteChapatiBeefstew.JPG
# 🧭 Detected: Black Beans
# ⚠️ Poor match for black beans in /home/aojwang/data/MergeDataset/images/1747WhiteRiceWhiteChapatiBeefstew.JPG (Score: 36)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1748WhiteRiceWhiteChapatihalfBeefstew.JPG
# 🧭 Detected: Thabai
# 🧭 Detected: Blueberry
# ⚠️ Poor match for thabai in /home/aojwang/data/MergeDataset/images/1748WhiteRiceWhiteChapatihalfBeefstew.JPG (Score: 30)
# ⚠️ Poor match for blueberry in /home/aojwang/data/MergeDataset/images/1748WhiteRiceWhiteChapatihalfBeefstew.JPG (Score: 38)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1749WhiteRiceWhiteChapatiquoertBeefstew.JPG
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1750WhiteRiceWhiteChapatiBeefstew.JPG
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1751WhiteRiceWhiteChapatihalfBeefstew.JPG
# 🧭 Detected: Thabai
# 🧭 Detected: White Rice Boiled
# ⚠️ Poor match for thabai in /home/aojwang/data/MergeDataset/images/1751WhiteRiceWhiteChapatihalfBeefstew.JPG (Score: 30)
# ✅ Matched white rice boiled -> white rice boiled (4.8g carbs)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1752WhiteRiceWhiteChapatiquoterBeefstew.JPG
# 🧭 Detected: Black Beans
# ⚠️ Poor match for black beans in /home/aojwang/data/MergeDataset/images/1752WhiteRiceWhiteChapatiquoterBeefstew.JPG (Score: 36)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1753WhiteRiceWhiteChapatiBeefstew.JPG
# 🧭 Detected: Black Beans
# ⚠️ Poor match for black beans in /home/aojwang/data/MergeDataset/images/1753WhiteRiceWhiteChapatiBeefstew.JPG (Score: 36)
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/1754WhiteRiceWhiteChapatihalfBeefstew.JPG
# ⚠️ No food detected.
#
# 📷 Processing: /home/aojwang/data/MergeDataset/images/
# 🧭 Detected: Murenda
# 🧭 Detected: Brown Ugali
# 🧭 Detected: White Ugali
# ⚠️ Poor match for murenda in /home/aojwang/data/MergeDataset/images/1790FishwetfryBrownUgali1CupSpinach.JPG (Score: 13)
# ⚠️ Poor match for brown ugali in /home/aojwang/data/MergeDataset/images/1790FishwetfryBrownUgali1CupSpinach.JPG (Score: 11)
# ⚠️ Poor match for white ugali in /home/aojwang/data/MergeDataset/images/1790FishwetfryBrownUgali1CupSpinach.JPG (Score: 21)

# %%
import matplotlib.pyplot as plt
import cv2
import torch
import numpy as np

# Sample image to visualize pipeline
sample_image_path = "/home/aojwang/data/MergeDataset/images/1Apple.jpg" 
food_items = preprocess_image(sample_image_path, use_ground_truth=False)

# Reload trained model
MODEL_PATH = '/home/aojwang/data/model/food_weight_model.pth'
weight_model.load_state_dict(torch.load(MODEL_SAVE_PATH, map_location=device))
weight_model.eval()

# Load original image
original = cv2.cvtColor(cv2.imread(sample_image_path), cv2.COLOR_BGR2RGB)

# Get YOLO detections
results = yolo_model(original, verbose=False)
detections = results[0].boxes
annotated = original.copy()

# Annotate image with labels
for box in detections:
    x1, y1, x2, y2 = map(int, box.xyxy[0].tolist())
    label = yolo_model.names[int(box.cls[0].item())]
    cv2.rectangle(annotated, (x1, y1), (x2, y2), (0, 255, 0), 2)
    cv2.putText(annotated, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)

# Start plotting
num_items = len(food_items)
fig, axs = plt.subplots(num_items + 1, 4, figsize=(18, 4 * (num_items + 1)))
fig.suptitle("🔬 Graphical Abstract: Food Carbohydrate Estimation Pipeline", fontsize=16)

# First row (headers)
headers = ["Original Image", "YOLOv8 Detection", "Cropped Food Item", "Prediction"]
for i, title in enumerate(headers):
    axs[0, i].axis("off")
    axs[0, i].text(0.5, 0.5, title, fontsize=14, ha='center', va='center')

# Populate rows
for idx, (label, img_tensor, features, _) in enumerate(food_items):
    # Row index in plot
    row = idx + 1

    # Column 0 - Original
    axs[row, 0].imshow(original)
    axs[row, 0].axis('off')

    # Column 1 - Annotated
    axs[row, 1].imshow(annotated)
    axs[row, 1].axis('off')

    # Column 2 - Cropped item
    cropped_img = img_tensor.squeeze(0).cpu().numpy().transpose(1, 2, 0)
    cropped_img = np.clip((cropped_img * [0.229, 0.224, 0.225] + [0.485, 0.456, 0.406]), 0, 1)
    axs[row, 2].imshow(cropped_img)
    axs[row, 2].set_title(f"{label}")
    axs[row, 2].axis('off')

    # Column 3 - Prediction
    with torch.no_grad():
        prediction = weight_model(img_tensor.to(device), features.to(device)).item()
    axs[row, 3].text(0.5, 0.5, f"{label}\n{prediction:.2f}g carbs", fontsize=12, ha='center', va='center')
    axs[row, 3].axis('off')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
# Out:
# /tmp/ipykernel_2372836/3175293217.py:48: UserWarning: Glyph 128300 (\N{MICROSCOPE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# %% [markdown]
# # TODO
# 1. Augmentation test
# 2. Background removal
# # Experiments:
# - https://pmc.ncbi.nlm.nih.gov/articles/PMC11887021/
# - https://arxiv.org/html/2405.16478v1
# - https://onlinelibrary.wiley.com/doi/10.1155/2023/6612302
